# %% [markdown]
# <a href="https://colab.research.google.com/github/II-DW/Colab-Storage/blob/main/CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5YbYCxhKMjrYuC1pdy5Q")
project = rf.workspace("clothesdetection").project("clothes-detection-ahxqo")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 38.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
# ...

# %% [markdown]
# > 파일명 dataset으로 변경해야함

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15994, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15994 (delta 18), reused 18 (delta 12), pack-reused 15967
# Receiving objects: 100% (15994/15994), 14.64 MiB | 14.25 MiB/s, done.
# Resolving deltas: 100% (10980/10980), done.

# %%
# !pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 82.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 108.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 112.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 64.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 37.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: Pillow
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# %cat /content/dataset/data.yaml
# Out:
# names:
# - block
# - horizontal
# - plaid
# - plain
# - vertical
# nc: 5
# roboflow:
#   license: CC BY 4.0
#   project: clothes-detection-ahxqo
#   url: https://universe.roboflow.com/clothesdetection/clothes-detection-ahxqo/dataset/2
#   version: 2
#   workspace: clothesdetection
# test: ../test/images
# train: Clothes-Detection-2/train/images
# val: Clothes-Detection-2/valid/images

# %%
# %cd /

from glob import glob

train_img_list = glob('/content/dataset/train/images/*.jpg')
valid_img_list = glob('/content/dataset/valid/images/*.jpg')
test_img_list = glob('/content/dataset/test/images/*.jpg')

print(len(train_img_list), len(valid_img_list), len(test_img_list))
# Out:
# /
# 2634 427 1355

# %%
with open('/content/dataset/train.txt', 'w') as f :
  f.write('\n'.join(train_img_list) + '\n')

with open('/content/dataset/val.txt', 'w') as f :
  f.write('\n'.join(valid_img_list) + '\n')

with open('/content/dataset/test.txt', 'w') as f :
  f.write('\n'.join(test_img_list) + '\n')

# %%
import yaml

with open('/content/dataset/data.yaml', 'r') as f :
  data = yaml.load(f, Loader=yaml.FullLoader)

print(data)

data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'
data['test'] = '/content/dataset/test.txt'

with open('/content/dataset/data.yaml', 'w') as f :
  yaml.dump(data, f)

print(data)
# Out:
# {'names': ['block', 'horizontal', 'plaid', 'plain', 'vertical'], 'nc': 5, 'roboflow': {'license': 'CC BY 4.0', 'project': 'clothes-detection-ahxqo', 'url': 'https://universe.roboflow.com/clothesdetection/clothes-detection-ahxqo/dataset/2', 'version': 2, 'workspace': 'clothesdetection'}, 'test': '../test/images', 'train': 'Clothes-Detection-2/train/images', 'val': 'Clothes-Detection-2/valid/images'}
# {'names': ['block', 'horizontal', 'plaid', 'plain', 'vertical'], 'nc': 5, 'roboflow': {'license': 'CC BY 4.0', 'project': 'clothes-detection-ahxqo', 'url': 'https://universe.roboflow.com/clothesdetection/clothes-detection-ahxqo/dataset/2', 'version': 2, 'workspace': 'clothesdetection'}, 'test': '/content/dataset/test.txt', 'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt'}

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data /content/dataset/data.yaml --cfg ./models/yolov5l.yaml --weights yolov5l.pt --name ball_detect
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5l.pt, cfg=./models/yolov5l.yaml, data=/content/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=ball_detect, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs

# %%
# !zip -r /content/yolov5.zip /content/yolov5/

# %%
# !zip -r /content/runs.zip /content/yolov5/runs/

# %%
from google.colab import files

files.download('/content/runs.zip')

# %%
from google.colab import files

files.download('/content/yolov5.zip')

# %%
# !unzip "/content/runs.zip"
# Out:
# Archive:  /content/runs.zip
# replace runs/train/ball_detect/confusion_matrix.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
#from keras.utils.data_utils import get_file
import numpy as np

import random
import sys
import io
import re

# %%
# path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')

path = 'data2.txt'
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()

text = re.sub(r'<.*>', '', text)
text = re.sub(r'\n', ' ', text)
text = re.sub(r' +', ' ', text)
text = re.sub(r'[0-9]', ' ', text)

print('corpus length:', len(text))
# Out:
# corpus length: 59842

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 1946

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 19934
# Vectorization...
# <ipython-input-4-7de617b7b4c4>:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-4-7de617b7b4c4>:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(1024, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.001))
# Out:
# Build model...
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    print('\n----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
#     for diversity in [0.2, 0.5, 1.0, 1.2]:
#         print('----- diversity:', diversity)

    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, 0.5)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y, batch_size=128, epochs=60, callbacks=[print_callback])
# Out:
# Epoch 1/60
# 156/156 [==============================] - ETA: 0s - loss: 5.0284
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "난디 그 뒤를 바라오니 그 때여 이 도령 비룡같은 노새등 뚜렷이 올라앉어"
# 난디 그 뒤를 바라오니 그 때여 이 도령 비룡같은 노새등 뚜렷이 올라앉어      "          도        루지         曹    만        "       (              니                                                                                    천    님 이   나 향                 도                              (소    내    )지  자              에     나   어               을     지        니           이 이            (              고     (니  (  이  은    하   니       이         을    느    시
# 156/156 [==============================] - 43s 266ms/step - loss: 5.0284
# Epoch 2/60
# 156/156 [==============================] - ETA: 0s - loss: 4.8395
# ----- Generating text after Epoch: 1
# ----- Generating with seed: " 상하야 아무 대답을 아니허고 대문안을 들어스니 그 때여 춘향 어머니난 "
#  상하야 아무 대답을 아니허고 대문안을 들어스니 그 때여 춘향 어머니난 가            어       가 이      이  도     드라                리         이리    아            하             을              하   이                  로                      복  이                        하                                  이                           이 만   리자     을    어 이 "     을                       으                "    .                     말 )               나        서     ,
# 156/156 [==============================] - 41s 266ms/step - loss: 4.8395
# Epoch 3/60
# 156/156 [==============================] - ETA: 0s - loss: 4.8126
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "니 금일송군(今日送君) 님 가신곳 백년소첩 나도 가지"     도련님도 "
# 니 금일송군(今日送君) 님 가신곳 백년소첩 나도 가지"     도련님도 문              만  "      이       "  정       기    "        "         "    자                         (    이       일     이       신      이사고 라         "    "  어 가 이" 니            옥  "     불 오    왔       어       "          디   어     "          "  "        나   (     이  에                       있 도      고  시  허        이              이                         이                                     서      "
# 156/156 [==============================] - 41s 266ms/step - loss: 4.8126
# Epoch 4/60
# 156/156 [==============================] - ETA: 0s - loss: 4.7874
# ----- Generating text after Epoch: 3
# ----- Generating with seed: "신발벗고 발에 먼질르 털며 혼자말로 군담허되,     "안다 안다 운봉이"
# 신발벗고 발에 먼질르 털며 혼자말로 군담허되,     "안다 안다 운봉이 "      "  가        지        지      "   "    "    한            이           서    이 "      "              님     이                사    "   "       " 이    "   이이         "      "은            "  "    " " 또  "    " 대  "       "   "   "  "   "  " 향이   "이  .이            아      시        나        "  "    들      "이  기  "        이 기     " 이       가          "     ("    이 "    "      나        "    들    이  "  고
# 156/156 [==============================] - 41s 267ms/step - loss: 4.7874
# Epoch 5/60
# 156/156 [==============================] - ETA: 0s - loss: 4.7589
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "은 죽을 판이로다 어화여루 상사디여 (후렴) 다 되었네 다 되어 서마지기"
# 은 죽을 판이로다 어화여루 상사디여 (후렴) 다 되었네 다 되어 서마지기    다  "                       나                                  다                     이            가  어  지      이   이                "       "  너이        양         향                  이  고  대이   "   "          향  향          "     "     이      내     "      "                      또    고 나  으                  "이  을 오  은        이           "           "    이                         향      " 이
# 156/156 [==============================] - 41s 265ms/step - loss: 4.7589
# Epoch 6/60
# 156/156 [==============================] - ETA: 0s - loss: 4.6563
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "런 가관이 없든 것이었다.         백구야 백구야 백구야 백구야 껑"
# 런 가관이 없든 것이었다.         백구야 백구야 백구야 백구야 껑    "  "        이 어" "      "                      " "  " 그  "   "  "    가        "   "                 "  한      어 "        " "          "        "     어 " "     "           어이          "   "  아 이     "    "    향    어        "    "   "          "    "  향       "              "    "   또    "    춘     "         " "        "         사 "이  어이       "               "     "                     "   "
# 156/156 [==============================] - 42s 269ms/step - loss: 4.6563
# Epoch 7/60
# 156/156 [==============================] - ETA: 0s - loss: 4.5164
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "어라 셋째낱부터는 안세를 두마."     "꿈쩍꿈쩍마라. 뼈부러질라." "
# 어라 셋째낱부터는 안세를 두마."     "꿈쩍꿈쩍마라. 뼈부러질라."       무이               "      이 이리     " 아은 아리                  치    주이  사       아아  아지다      "이 "  사          리이 "여  사       아이하      이 이 이  주보              아이       자니 이  어 지을 "       아이 춘서        아이  아  하            오고 보어  보  동 이다      아 들리  이       러리               아 춘이       " 이 이자이          아고 여        또 하라              아라니 " 도 나어          아이            아 이이 아 도를이              보이 춘 사고 여은 이서
# 156/156 [==============================] - 41s 265ms/step - loss: 4.5164
# Epoch 8/60
# 156/156 [==============================] - ETA: 0s - loss: 4.3762
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "미인을 극찬하는 말) 허는 태도 보는 중 처음이요 짝이 없는 일색이로구나"
# 미인을 극찬하는 말) 허는 태도 보는 중 처음이요 짝이 없는 일색이로구나        춘어 모도      "등      보고가  두 여고 춘어 어          춘사이 나아 보어 이                                      방이 부어 들어 춘루 어고 그어 다 춘이 남르 하어 부      " 그사 모 허이 너리      "이 마고 허가 말은 아으 여이 지리으     ""  신 아고 내장이  두                            그이 이 부라 기도 삼  수  어 상고 들라 가고 나       "                       나여 말이 말어 말고 나르 말              가이 마리 어 이고 다다 다        으고 어어                              사어를           여어 마을 모어 나이 춘어
# 156/156 [==============================] - 42s 268ms/step - loss: 4.3762
# Epoch 9/60
# 156/156 [==============================] - ETA: 0s - loss: 4.2628
# ----- Generating text after Epoch: 8
# ----- Generating with seed: "淸風)의 백구(白鷗)난 유랑(遊浪)이요. 녹림간(綠林間)의 꾀꼬리 환우성"
# 淸風)의 백구(白鷗)난 유랑(遊浪)이요. 녹림간(綠林間)의 꾀꼬리 환우성 사며 노한 내 주이 이 방              이은 춘향 말자 부 은      아사이 내                지이 !우 부다 죽고                이 이히 이 이줄 조         모이  도 이까 가 허는 보반가 보 어 없고 누어일      향이 이 말이 나고 부여 말가 발리라 다 일 들면 나이 신이 광를 말을 이 들경 이 수고 잠 은 보을 말어 나               이 이  어 저지 이 세르이 나다 다은 소련 이                아또이 어                        이 춘향이 만          여 말어 보 하고 잠고 춘이 소고 어 부 이 소을 어가 되자 모이 말어 이 말리 죽              이리가 오어 부하이      향 이고 말다 그이
# 156/156 [==============================] - 41s 266ms/step - loss: 4.2628
# Epoch 10/60
# 156/156 [==============================] - ETA: 0s - loss: 4.1731
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "로 다 충비로다 우리 향단이 충비로다."         "향단아 그만 울"
# 로 다 충비로다 우리 향단이 충비로다."         "향단아 그만 울               이 이향이 내     "향이 그이 없녀 말                                                                                                                                                                              "                                                                                                                                                                     이 향향이 이 들방 나이 남 생르이 어어
# 156/156 [==============================] - 42s 269ms/step - loss: 4.1731
# Epoch 11/60
# 156/156 [==============================] - ETA: 0s - loss: 4.0981
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "환(指環)벗어 도련님께 올리면서,     "여자의 굳은 절행 지환빛과 같"
# 환(指環)벗어 도련님께 올리면서,     "여자의 굳은 절행 지환빛과 같람로 이 도 지에 어다고는 자인시 어 무을 백어 아 말을 이 허락 이 수에 거어 오이 쫓어 허의 무을 어에 아은 내 부여고 내 말면 춘향이 나 들을 어 이 이지,     이아 이 도어 하의 가 허리라 나이 어어 어어 어어 그이 일아이     "이 말고 아어를 나리(? 허이 나고 아러 알은 "           이고 어어 좌이는 이니 나어 말리 만에 어어이 이 또에 이 그 소고 어도는 이 계르을 나니 알어 죽라고 어 하냐 술 이은 이 허을 이 각에 나니 바지이 어 부 허를 장이라이 되이라고 어가 이로 죽어 서고 아으로 이 나고 보어 내리 도 죽어 이 들각 시어 사고 수고 일고 허고 가이 없어 아고 춘향이 가을 기라허니 남어 어이 내 있고 들러이 나거로 가라니 이 들러     "이 일고 어리 못어 아이니 이 되
# 156/156 [==============================] - 42s 268ms/step - loss: 4.0981
# Epoch 12/60
# 156/156 [==============================] - ETA: 0s - loss: 4.0341
# ----- Generating text after Epoch: 11
# ----- Generating with seed: "문(亂杖刑問)에 주릿대 방망이 마줏대 망태거리 학춤을 추면 굵은 뼈 부러"
# 문(亂杖刑問)에 주릿대 방망이 마줏대 망태거리 학춤을 추면 굵은 뼈 부러 이 말리 마 갈     "
# 156/156 [==============================] - 41s 267ms/step - loss: 4.0341
# Epoch 13/60
# 156/156 [==============================] - ETA: 0s - loss: 3.9707
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "리 내가 죽어 삼월동풍 연자되여 임계신 처마 끝에 집을 짓고 내가 노니다"
# 리 내가 죽어 삼월동풍 연자되여 임계신 처마 끝에 집을 짓고 내가 노니다니 어를 생고 만어보고 "두 이리 나고 상어 일어 이리하야 그에 이     "이이 이 이이 춘향 이라 나다 내 있이 나어하니 말거(이) 이 없고 춘향이     "" 이이 소니 춘향이 이 만 이 이 하이 이 나이 못소님 이 기내 오은 기으하니 우을 사어 나이 여어 내는 들어 분어 말이 나     "오이 이 아련님 내     "춘향이 이 나라 이 말이     "오또님 이 이     "이 이 소이 춘향이 아어 소하이가 내 마 하에 이르니 이 말이 이 내 춘향이 못     "어또 이 이 들어 마련님 이 말어 나나 이 이     "이이 아은 이 다 주이 이 하려 나지 나는 기어 새      "향님이 우너 이 간 죄 이 이라 마지 모씨 못어 두에 춘향이 이 나 이 하이 이 하어 들게 이 주리     ""     "아이
# 156/156 [==============================] - 42s 272ms/step - loss: 3.9707
# Epoch 14/60
# 156/156 [==============================] - ETA: 0s - loss: 3.9037
# ----- Generating text after Epoch: 13
# ----- Generating with seed: " 질목 짚신 감발허고 주령을 끌면서 독담무를 지내어 숙고개를 얼른 넘어 "
#  질목 짚신 감발허고 주령을 끌면서 독담무를 지내어 숙고개를 얼른 넘어 가     "치이 이 여을 나 장 없도 도 보이라 아이 말로 알 허에 들 이 일 보 없에 되라 그 이 지여 나서 방 허겄     "이 이 개 하겄 이 아이 도 부리 말로 이 옥 이 없고 내 것이 나 가 이 보고 사도 없어     "이 알신 이 밤사 이 없는 내 내 이 보니 그 말로 어 허에 ! 보라 양 없리 세 떠주 이 아고 주 보는 동는 죽어 사도 죽고 무어 가 보으니 도                                           이 이 부에 그성 아로 왔로 오내 물 허고 오으라 왔 수 한
# 156/156 [==============================] - 42s 267ms/step - loss: 3.9037
# Epoch 15/60
# 156/156 [==============================] - ETA: 0s - loss: 3.8443
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "향의 설부화용(雪膚花容) 남방에 유명하여 감사(監司) 병사(兵使) 목부사"
# 향의 설부화용(雪膚花容) 남방에 유명하여 감사(監司) 병사(兵使) 목부사((明東)) 동聲 두 대 보고 두가 있어 두 이 바고 이 보리 소 이 헐가 보니 정 이 보 보 나 이 일 부 없 부도 도어 어 일이 마더니 이 아 이 다니 오자 오라 거정상이 보가 이 보 허니 말이 어어 이 리어 오 내 어 통 줄 이 나 성서 아 가 보고 아 사 이 일어 도련님 이 가리 오 네 한 보수니 어 양     "이 가 이 도 노 사또 이 기지라 너 운이 어 보었!"     "아이 가 허니 아 어 아아?"     "이 만 말을 들어 오을 오어 오 보 어 도 바어 아도 그 이 보이 보도 이 보에 저     "어 자가 절이 간어 말을 이 보르라 도련님이 소리 허 수 이 없어 가 보르니 하가 여 보이 없랑 그 이 말을 들을 있르니 청 남 아어 어가 이 들어 어 말이 바 상어 사어 이 달 도 이 옥자 좋 아
# 156/156 [==============================] - 43s 274ms/step - loss: 3.8443
# Epoch 16/60
# 156/156 [==============================] - ETA: 0s - loss: 3.7701
# ----- Generating text after Epoch: 15
# ----- Generating with seed: ". 즉자허니 노친이 계시고 사자허니 고생이로구나 죽도 사도 못허는 신세를"
# . 즉자허니 노친이 계시고 사자허니 고생이로구나 죽도 사도 못허는 신세를 하도 가 이 이 일 보에 글도 한 하방이 오도 되고     "이이 이다 부방(에 :은 아이 오지 오자     "이     "향이 춘향이 어어     "아이 내 향이 내 보이 춘향 이 하에 이 일이 없거니 그 거이 가 보 희 사또                방여 나자 이 듣 그     "이      도련님 이로 들어 자거주 나 보랑 차느방 우리 바이 보어 보도 없이 내                                                       방향오 춘향 말을 아고 보이 말이     ""이 어 너     "아이 대향이 내 단 하이     "이                                                   방이 우을 그 가 사람 이 말이 하니 글     "이 방
# 156/156 [==============================] - 41s 266ms/step - loss: 3.7701
# Epoch 17/60
# 156/156 [==============================] - ETA: 0s - loss: 3.6914
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "원성중이 뒤넘는디 좌상의 수령네는 혼불부신(魂不付身)하야 서로 귀에대고 "
# 원성중이 뒤넘는디 좌상의 수령네는 혼불부신(魂不付身)하야 서로 귀에대고 생之 려 동 만 그 허 마 나     "아 대 이 듣어 너소 말이 말어 도 저 말이 간어     "아 한 대을 어려 소 이 보고 나게 밤 가 없이 보더니 나                                              "아에 춘향을 말어 웬여 내 보고 죽아 나 보이 소 나 한 보 듣 보 보 있 이 주르 네 구이 허고 너인 고                 향향모 춘향이 듣 하고 다 보에 나는 어어 어가 오어 이 화 하고 고 보어 죽 방                 이통 춘향이 어 오 한 말이 어더서 웬 한 없이     "어         "향라 춘향                         "향 말이 춘향의 그더 어더             "
# 156/156 [==============================] - 42s 271ms/step - loss: 3.6914
# Epoch 18/60
# 156/156 [==============================] - ETA: 0s - loss: 3.6010
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "대저 귀신이라 헌느게 배풍어그허어고 승천입지(昇天入地)허매 춘향의 꿈 혼"
# 대저 귀신이라 헌느게 배풍어그허어고 승천입지(昇天入地)허매 춘향의 꿈 혼련님 어 가이     "이 한 좌 듣고     "도련님 이 것이라 아 가거 보느 다 분 나리 저     "이 한 가어 이 보이 보단 오지 저    "여만 저 다 먹리 내     "아이 춘향이 웬이 허어 들어에 예 없이 나             그리 향향     "이 내     "이 웬가 이르?"     "그가 향자 그 보을 내어 다     "아니 아가 웬어 보고 나는 일이 아어 네 어     "아이 아 허리 들어 여도 보어 저 이지치 나 가 나 나 나 저     "이 내 때경 어 도련님 이 말이 나도 글을 살고 마음이 웬르다     "아이고 여리 들른 좋이 그리 웬이 바식 만 보르     "이 이리 어가 어리 글더이 웬     "이 이로 나르 그     "아이 이식이 나만가 허는 들어 허고 나여 서 죽이 웬
# 156/156 [==============================] - 42s 269ms/step - loss: 3.6010
# Epoch 19/60
# 156/156 [==============================] - ETA: 0s - loss: 3.5107
# ----- Generating text after Epoch: 18
# ----- Generating with seed: " 제 문전의 청삽사리 킝킝 짖고 쫓아 나오니 건넌방 춘향모친 개를 쫓으면"
#  제 문전의 청삽사리 킝킝 짖고 쫓아 나오니 건넌방 춘향모친 개를 쫓으면 나 한 거지 다 마은 지 마음 내 눈어 내 보리 마지 마으     ""     "아니고 나 여히 왔지가 말을 나고 지 보어 부 하여 나 보었라.     "이 자가 올 보자 나 놈이 나 마었라"     "아니!"     "나니고 춘향이라 나 마라 서 위을 허니 허니 이 팔는 나 주다."     "아이고 나가 말이 있신하고 나 형을 나 보고 춘향이 없르니 내 마연 마리 내가 한 보었니 들 죽에 청문이 이지 다가 나 보니 소리 죽이 나 허니 나지를 내 이리 내 부이 없어 지 마는 나 이 없고 저 수이 없나."     "아 나 수 것에 다더니?"     "나 내 나 말이야"     "이 내 부 허어 너리 듣으로 나 보이 나 이 없어 없을 저 나 없어 마지이 나는 내 수에 없락 없이 날 보리 도련님 이 상원 물 수
# 156/156 [==============================] - 41s 266ms/step - loss: 3.5107
# Epoch 20/60
# 156/156 [==============================] - ETA: 0s - loss: 3.3973
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "랑다랑 훨훨 너머가니 그때여 춘향이 난 따라갈 수도 없고 높은 데 올라서"
# 랑다랑 훨훨 너머가니 그때여 춘향이 난 따라갈 수도 없고 높은 데 올라서 웬가 오서 들어 불이     "아이 이 웬이 ! 어 어라 우더니 갈 말이 춘향이 나 주이 없어 다 장이 없어."     "이 이 하을 들어 말이 나오."     "이 자서 들어 말이 내 보이 나겄다.     "이 이 가 듣는 그 하는 우어 아이라. 하라 말이 들어서고 내 구 어 거리 아니 말이 나 하고 마는 나 보이 없다. 너이 들어서 오 다 없고 옥더니 사또 기을 날 보이냐"     "내 이 듣리 나으니 말이 보어 어사또 말이 지고 일이 없어 나도 말을 여어 저     "이 일 이 듣어 춘향이 춘향이 여루 대장 나으니 오니 만어 어서 죽어 어사또 아 성이를 동어 지디 나으니 춘향이  어 이니 떠 이 울어 주서 장어 단이 마어 내 이 없고 내머없니         "어 그었니 춘향이 나는 이 보느 오는 내
# 156/156 [==============================] - 43s 275ms/step - loss: 3.3973
# Epoch 21/60
# 156/156 [==============================] - ETA: 0s - loss: 3.2740
# ----- Generating text after Epoch: 20
# ----- Generating with seed: " 펄쩍 열고 바라 보니 도련님 청중추막자락이 바람결에 휘날리고 담배불로 "
#  펄쩍 열고 바라 보니 도련님 청중추막자락이 바람결에 휘날리고 담배불로 자문 말을 나니 세삼을 불절 기고 허각 오사 님이 보다 다 춘향이 허는 그 하고 나도 일을 한 날 도련님하로 여리 수 이 을 있는 춘향이 없오 되어 날 도 이렇 소리 한 들어 .     "아 허으면 춘향이 자리 그자 어다 죽을 내지 사람수나 이리 그다 기 하이 없다.         춘향이 이 이 말을 나하오."         춘향이 이 말이 들어 내 편이 웬오 말이 가다 일 수이 힘다 오람주 아은 도 하여 사문의 후은 살고 지만 기삼을 가다 이고 나더니 나 수수 청에 가 갈 없이 바우 나 일 이 말이 소다 한 대이 없다 여가 찾가 그 일 저 상에 다리 그어를 저다 다 주 수 가 도련님이 아시 되고 찾연이요 네         그리 춘향이 나 마리 도련님이 허리 것이 들어 다고 나오 그일 풍 하로 마리 도련님이
# 156/156 [==============================] - 42s 269ms/step - loss: 3.2740
# Epoch 22/60
# 156/156 [==============================] - ETA: 0s - loss: 3.1442
# ----- Generating text after Epoch: 21
# ----- Generating with seed: " 왕하신단 말씀은 금시초문이요."     "네 모르는 말이로다. 태고라 "
#  왕하신단 말씀은 금시초문이요."     "네 모르는 말이로다. 태고라 나나 들어     "보이 춘향하가 춘향을 되어서 우도 말을 나르나 도련님 나는                                                        방방을 들어허고
# 156/156 [==============================] - 43s 275ms/step - loss: 3.1442
# Epoch 23/60
# 156/156 [==============================] - ETA: 0s - loss: 2.9820
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "이는 삼충사에 올라있고 안동기생 일점홍이난 열녀문 세워있고 선천기생은 아"
# 이는 삼충사에 올라있고 안동기생 일점홍이난 열녀문 세워있고 선천기생은 아시다 춘향 장에 보시기다.     "이 이렇 반이 자 보더니 말이 나고 서 없이 웬지 가어라 하여 일어 글 수 없고 저 도련님 마는 이 보 마지."     "이 자루 너르이 웬 말이요 말이 말이 내 말이요 잠     "아이 춘향이 춘향이 내 일었시고 이리 일이 나지 말이라다."     "이 이 소반이 소 한 말이야?"     "춘향이 내 사람이 갈 말이요?"     "이 이 주 "     "말이라 이 웬 불 야 소리 춘향이 없절하나     "이 이 소 을 듣르야 이 없어 그     "이 이 하을 너리 너 말이라."     "이 한 이 가다 춘향이 말이라 말이 웬여 보지다."     "이 이 너 야 말이냐?"     "사또님 이 충식 보지 도련님 오여 일이 보다 춘향이 없느 달어 가를 가소를 허고 지라.
# 156/156 [==============================] - 42s 270ms/step - loss: 2.9820
# Epoch 24/60
# 156/156 [==============================] - ETA: 0s - loss: 2.7905
# ----- Generating text after Epoch: 23
# ----- Generating with seed: "     도련님이 아무 대답없이 방문열고 들어서니 그 때여 춘향이난 촉하"
#      도련님이 아무 대답없이 방문열고 들어서니 그 때여 춘향이난 촉하는 나 부러러 하니 도련님 나 무이 있고 오 못 없고 새도 그가 일 수 딸 두도 한 운이요 말이리 그 보아 나는 !"     "아이 춘향이 아 듣려 아 오었니 떠 상이요 오 어 아이라?"     "어 한 방인야 나에 그 있었느?"    "이 등렇의 네 자르요 춘향이 가 무수 아니고 내 한 말을 보니 보어 오수     "아니 춘향이 들어서 우리도 없다."    "아 내 부반 듣었자면 말이 웬일 내 어는 있는냐?"    "이 모                       운방의 썩향는 아니 그 좋었라 오 한 모아 우러 어락느느?"    "그 등기 듣르 말이라?"     "이 한 자지 다 웬일이나?"    "어 이 소인 너에 어     "말이 저 먹어 웬오느냐?"     "예방님 절명"     "허니 춘향이 도련님
# 156/156 [==============================] - 42s 273ms/step - loss: 2.7905
# Epoch 25/60
# 156/156 [==============================] - ETA: 0s - loss: 2.5803
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "도하야 글 한수를 지어 읊었으되 춘향 상봉할 글이었다.       교명오"
# 도하야 글 한수를 지어 읊었으되 춘향 상봉할 글이었다.       교명오 나령 사또 호문 좋에 일 나고 지었이냐. 너     "네 계디 반식 다 말은 내     "네 놈 허고 달 향에     "향생 미럼 너르다 오리 일일이 웬단하야 집련님 남     "단이 춘향이 들어서 보와 내     "아이 춘향이 웬 이었니 그리 일이 내가 어찌 마라 일 보고 일 하여 일 수이 없으니     "아이고 아니 도련님 아 듣아 알려 만일 지수 일     "아이 춘향이 들 어상고 만느 일이 들어 보고 가고 생각 가 없이 없니 한중이냐 일기 대고 들어가 제 것이냐 웬 하어 일 어이니 잠상 도련님 남 반에요 잠         춘향의 향향 달리 마더로 수수하여 그 도련님 춘향이 춘향하고 여 어떤 내 었어."    "이 자식 반은 들어 보자 일어가고 취 마고 지느니 한 속이요 어찌 어서 못 한 아니 되를
# 156/156 [==============================] - 42s 271ms/step - loss: 2.5803
# Epoch 26/60
# 156/156 [==============================] - ETA: 0s - loss: 2.6778
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "짓노라 저녁연기는 자욱하여 분별할 길 전혀없다. 춘향집 문전 당도허여 취"
# 짓노라 저녁연기는 자욱하여 분별할 길 전혀없다. 춘향집 문전 당도허여 취사를 앞을 나소 오도 모르더 불시를 장주 주장 좋들 보어 가를 수가 나는 가소."    "사또이 다 말이 듣더니 너 아니 저 보겄다."     "그 자 보너게 너 자 말이 나는 보었고 저를 모저 나라 그 편리 있다."     "이 고 김 말이야 아보니 오리이 나는 기모 어사디 말이 도 어주며                                     춘향을 이리마소 어찌되어 장장가 같을 들어 이렇라."     "그러! 여보니 사령님 백수듣는 말 어사또 단을 없이 보니 만장 저이 없다."     "아이고 우었다!"     "예방! 그리마다.     "아이고 초머자!"     "이지고 어머리 갈 말을 저 보느 말이냐?"     "예 ! 부인도 갈 보어 말이냐?"     "이 하너 너자 너 자자 저 불었다.
# 156/156 [==============================] - 42s 269ms/step - loss: 2.6778
# Epoch 27/60
# 156/156 [==============================] - ETA: 0s - loss: 2.1988
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "  "잘 가든지 마든지 허제 분유헌 통에 쉰사라니 그럴일이요"     ""
#   "잘 가든지 마든지 허제 분유헌 통에 쉰사라니 그럴일이요"     "아이고 이리 무사또님이 금령이요 저 한자 어소 이자야 하각다 저 하여 어서 내가를 뚝 기이냐 저 한 아니야 정절에 상차하고 놀은 두고 들어가 도련님이 되아 나고 나가 나혀 글 거자나 남다 속은 간을 이 있다."     도련님이 듣어서,     "아이고     "오니 저근 너르더니 국을 아이 오려 어사또 취의 대에 듣고 다고 다가 나지다.     "아이고 춘향이!"     "내방님의 그령 오시시오 기생 수전을 부각허고 춘향이 들어 두정 두에     "이 야로 애아나 아 어만 주단이나."     "내 하내 너자 너더니 말이이 허고 그라 오더더마"     "그른 내 다리 달문이 춘향이 나오허고 편은 기생이 부어 한고 저     "이라야 춘향이 춘향이 가거로 장지 자리 지소 지라마마"     "그방은 여다 오말이
# 156/156 [==============================] - 43s 275ms/step - loss: 2.1988
# Epoch 28/60
# 156/156 [==============================] - ETA: 0s - loss: 1.9260
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "吏房隨陪) 형리통인(刑吏通引) 급창나졸(及唱邏卒)이 옹위(擁衛) 하야 권"
# 吏房隨陪) 형리통인(刑吏通引) 급창나졸(及唱邏卒)이 옹위(擁衛) 하야 권사또 파명치네 귀두없로 이었소라 어가 수러 죽니 와 반자라 한     "네 춘향이 썩 듣라 오 어가 오소. 그 사람 내가 네 어라 소소 혼 저 저 아니 우리 어가 못 수 없네."     "춘향이 가나니 그어 그직로 말이 도련님이 되어 지서며     "아이 춘향이 아거소 그리 일 지지라. 상수 사또 내 말이요 내 노에 서도님이 되어거면 이리히 하겄는 그 일이 없어 다 수이라 웬 일 아 아 년 새는 일 그리네 내 가 없린 안너나 일거면 내 저 방고 내가 도련님이 되어허고 내 도 이 소리 이 말이 없어 만 수 말이 아 하여나 내 한 이 웬 번이야 내 먹 아 일     "네 말아 난 너어라 오 없어 떠)이 도련님 얼고 팔었라디 마패자 못 허르니 사또 말은 허었시면 그가를 서서 우어 앉이다.     "아뢰고 이게 무
# 156/156 [==============================] - 42s 271ms/step - loss: 1.9260
# Epoch 29/60
# 156/156 [==============================] - ETA: 0s - loss: 1.6457
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "도리어 상심허여 거문고로 울음을 대허오니 육현이 끊어지고 글귀로 회포를 "
# 도리어 상심허여 거문고로 울음을 대허오니 육현이 끊어지고 글귀로 회포를 아아 고소리 마음 이 주룡 마음 얼씨 륵라 사람을 불리 아고 간 수에 없다 다 어떤 소리보더 아중 그제 기도 마라더 너 그르고 서리 울가 웬지 마라 저 사람이 영를 무르고 것하을 불가 오라며     "아이라 춘향이 나 듣기 춘향의 좋리 전 어지고 마음도 이 일이야 오 속 당 마는 마는 말이 마는 소리난 이 도 아니 저 것이야 아니 내가 저 보아니 오음없이 듣다 기장 좋은 가루 너디 가가더니 너마없이 못     "아이 춘향이 춘향아! 이 구딱 어사또 춘향에 집 대 저 주니 너디 어가 해가 마는 못 사람아 더생 너라     "아이라 춘향이 들어가라 오리 나라 나지 말이 나가 무소 여라 가 마리.     "춘향이 이 춘향 어가 듣더더!"     "자동 기가 너지더니     "허니 춘향이 들어가라 여 편으고 기생이
# 156/156 [==============================] - 43s 276ms/step - loss: 1.6457
# Epoch 30/60
# 156/156 [==============================] - ETA: 0s - loss: 1.3706
# ----- Generating text after Epoch: 29
# ----- Generating with seed: "   "거 무엇이드냐?"    "다른 무엇 아니오라 이 고을 퇴기 월매 "
#    "거 무엇이드냐?"    "다른 무엇 아니오라 이 고을 퇴기 월매 혼진육신 不엇 남어디 부담가 없어가니 소리 사리 끊 기이냐 일 일 아고 올디 울여!"    "하이 알 어서 노기 너르야 말이 도자님 나는소?"     "이 자겠 너식 디 말하야 말을 들어가라니,     "나이 춘향이 들어서며     "아이고 엄이 도련님이 시고 편자님 저 구리 못디 네 일이라니 아니 오고 나 기일이 웬할 기고 불검육 집다."     "아이고 어머니 무 이 기는 보더니가 말이냐?"    "이 등 이 말을 들어허고 말이 된일이고 어 상어 저내 가락허나 너 기상에 죽심가 가는..     "아이고 어머니 갈 노을 아게 해아나"     "아 하여라!"     "이 얘 저반 일방에 코혹와 지느는 오느냐 춘향모친 흉 대발이 있었다.     "아이고 춘향이 들어왔고 세 한에 있신이 들어서니     ""너
# 156/156 [==============================] - 42s 270ms/step - loss: 1.3706
# Epoch 31/60
# 156/156 [==============================] - ETA: 0s - loss: 1.1083
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "허실 량으로 책방의 목낭청(睦郎廳)을 청했겄다. 낭청이 사또 턱밑에 바싹"
# 허실 량으로 책방의 목낭청(睦郎廳)을 청했겄다. 낭청이 사또 턱밑에 바싹거며 어사또 남장 수어사라 만금사디 못성인 바문제 단주 무어 고천으로 나오 오삼 남생 네 대아 없어 내가 만다 마는지겠 일하이라 일 그지고 이 보어가 .는 없고 하는 도련님 오여 주주 섭지 지점 내가 대줄 내가는 구다. 어주고 말을 생일 나만 저도 마여 서도련님 마는 리     "이리 춘향이 아 적와 일 보었라."    "아니 내 자람 말이 있게 그만단야 저리 홍라도 못을 일이나."     "네 자대 반은 들어 사또허게 말이 다어 저도 못주보느"     "아이고 이 자식 일문에 말이 여려 만소고 여주여,     "아이 춘향이 들 운겄고 저도 말좀 보는 저소 여소 저 사랑 없소 마는 오여 만도도 좋든 해는 바도 만마는 나는 나는 나면 도도님이 보아허고 저 도 주경 하하하야 가월기허고          그리 오나
# 156/156 [==============================] - 43s 274ms/step - loss: 1.1083
# Epoch 32/60
# 156/156 [==============================] - ETA: 0s - loss: 0.8690
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "려라."         골방의 수청통인 우루룰 나오더니 급창     "예"
# 려라."         골방의 수청통인 우루룰 나오더니 급창     "예라 춘향이 들어가라 장인의 모쳐라 부거부듯 이 딸 글나 다만 다. 저 수도 없어 다여마라!     "네 ! 방지야 약 었어가 춘향이가 이리 남단 기방를 부한 한     "아이 춘향이 어지운!"     "워방 하나는 명수 장 대자 있느냐?"     "오방님 상지사또 춘향 을 찾어 보니 춘향집에 이 되어 어찌 가소?"     춘향이가 춘향이  어 무전 술신 소리 저찌 신신이 구겄하니     "이 라 춘향아 소리비라 어찌     "너라 춘향이 아냐오?"     "예 ! 이 물수물"     "허허니 춘향이씨 이 웬수의 이르야야 술으로 서서 가가 우소 그가 저어 소상만 나 이리다 어가 오고 글공방야 도지상년 송음을 모르. 오 그리 연지지마는 가 눈 아고 새은 자요 잠간 생아 마사지 없은 오지 저     "이 저저 이
# 156/156 [==============================] - 42s 272ms/step - loss: 0.8690
# Epoch 33/60
# 156/156 [==============================] - ETA: 0s - loss: 0.6595
# ----- Generating text after Epoch: 32
# ----- Generating with seed: "더러 찾아오란 뜻이다. 춘향집을 일러라!"    방자가 손을 들어 춘향 "
# 더러 찾아오란 뜻이다. 춘향집을 일러라!"    방자가 손을 들어 춘향 어가 저어 지고 한 보고 저가 보어가 갈일나 집감 지가 지도 내마나 나는 모르席 나 오든 말이 되어 머거거 나         춘향이친 썩오 들어 잡수(과上)의 수루허렁 변하한 광 일이요 어사또 복절을 허아 오장 이 도련(映夫)가 소로 들어 거만 수 지리다 갈우강 먹무 내 푸낭상이 도련들이 내서 자며     "허보 춘향이 나 듣라라 춘향은 나나 놀려 이고 저위 바이 웬일 단라시든 단당이 못세허니 그리 말을 들어주고 군부에 도른(게鑑)허고 춘춘향걸 다지 남으 만 향이 도 내 일이 있음 장수하( 썩兵枝(고지허허허지 사람 두쳐 소도 한 바리 물도 중중 살은 고 수방에 걸느지라!"     "그러 말다 너른 춘향이가 나오가 것이 도지 만소지라."     "내가 본너 무자 내 말이 소리 보단가 말이가 한 떠 도자 보주
# 156/156 [==============================] - 42s 271ms/step - loss: 0.6595
# Epoch 34/60
# 156/156 [==============================] - ETA: 0s - loss: 0.4841
# ----- Generating text after Epoch: 33
# ----- Generating with seed: " 관문앞을 당도허니 벌떼같은 군로사령 와르를 달려들어         "옥"
#  관문앞을 당도허니 벌떼같은 군로사령 와르를 달려들어         "옥문인이 썩을 들어 아니하로 말을 나라 어사또 말을 가지마니     "이 모식 춘향 어따더더더도 말이시다.     "죽이 사사또 우조히 이게 오게 내가 있소?"     "너 알장 너식 싫더니 방은 편신 보는 저 흔자라다.     "사또 이가 말,     "오가라 아단마는 나가서 남지 춘향지지 사람하나 좋다 멀어 나가라!"     "아이고 신, 무식밥에 얼겼의 만실 손지 사지나나. . 앙으씨 기너가 말이. 어가 춤웃을 불러주여 저마도 이지갈이 다게 듯을 들어보니 군비 말이 건綺맺세 내       춘향모가 이 년 듣아 보려 보었나?     "예  번방 역문데 그은 오더니 내 단단에 구니 가라니 내놈 생시시더"     "이 부너의 물석 들어가지?"     "나지 너음의 우른 춘이 있시는 어가 고라보면 말을 모하나
# 156/156 [==============================] - 43s 277ms/step - loss: 0.4841
# Epoch 35/60
# 156/156 [==============================] - ETA: 0s - loss: 0.3455
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "이매어 춘향손을 부여잡더니 누물이 듣거니 맺거니     "오냐 춘향아 우"
# 이매어 춘향손을 부여잡더니 누물이 듣거니 맺거니     "오냐 춘향아 우지운라 장라럽 남왔을 부려부자, 마는 나서 죽어 고 글내 가 알일나지 아목 사람님이 시면하나 저리 대도(등撰:그옵하고 허고 사람 넣넣홍지 자리 고고 오고을 오리허고 내 호고 고 인비날비 춘향나가 거나. 놓은은 절이 날어서니 글아 사또님 못 부르고 내 가 주고 죽너와야 저     "이 놈 애 딸 한 그르소.     "아니니 기상하여 나오없고 춘향이 보시리디 들어가고 서도도 못어가 없는 듯이 든돌이 참 속소? 네 사람이 떠허니라 내 형경도 하는가라 내 수경이 절절하여 내 내희도 열은 놓어 간상하 소리하고 날 낭 골경을 깨도었는 내 내 도 은 방상하야 가가 죽고 내가 되어     "나이 춘향이 날 운은 오 가리소. 태한 너여 기너을 나도허니 내 정이 나 너 없이냐. 그리마라여 어가지고 ."허는 춘향지고 자리거고
# 156/156 [==============================] - 42s 271ms/step - loss: 0.3455
# Epoch 36/60
# 156/156 [==============================] - ETA: 0s - loss: 0.2478
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "이요 나를 찾어오신 낭군 어찌 그리 괄세하오."     "서방님"    "
# 이요 나를 찾어오신 낭군 어찌 그리 괄세하오."     "서방님"     "오방자헐 나진 들어 글문의 호리를 허겄다니 도련님이 로입허고 용부부를 허어다고 용제 말을 허어서다. 의 죽아 한 지게."     "아 고 방반 그리 어찌울게 이것이 나는 그리가 말이 도련님이 소씨이 나면 허를 바모지이 다면 모모 이로 저가 죽어가 없거나? 광남이 알른지지(몸重氈) 말 세 연인 가가 걸依 젓벽(네 )이네 어서 매를 건지들이 지아 나오 오황이 나오 무르고 나     "네 별슨 짖리 도련이 도오하여 거수(醉벌)허고 가실총 시시시면 삼문( 暫)을 모몽하여 춘향이 대대(홍솟)허고 된고 한족 넣으로 청산무복복 아고 여고 고 죽발걸 죽고 고하고 지지없(나白): 그별 윤렁 발(상넣자 상아네 라시오소합멀이           그경차 그다 그 노쌈 호호청 칭어 어찌 신소라."     "사또님이 도련님 도련님
# 156/156 [==============================] - 43s 278ms/step - loss: 0.2478
# Epoch 37/60
# 156/156 [==============================] - ETA: 0s - loss: 0.1771
# ----- Generating text after Epoch: 36
# ----- Generating with seed: "향의 설부화용(雪膚花容) 남방에 유명하여 감사(監司) 병사(兵使) 목부사"
# 향의 설부화용(雪膚花容) 남방에 유명하여 감사(監司) 병사(兵使) 목부사(長使使)의 꾀세(郡公) 나서 만나 파어지((羅靑使) 분역 보고 정정성((布廛深) 정수 (년안) 부(수약)이네 이러거리 되너 소라 절도비( 輾江같을 분어 아 소리은 헌세지복 적러없이 구듯 된어 지를 죽고 살은 가가 한가 들어가 서다. 너제 말도지(통비白) 그무를 불 가리고 열무허고 재이 없어 차세님(나境落)) 어슬 물을 발아니 북띠띠는 전러없고 이듯없오 을 줄었고 툭시시는 내뜻내나 다려리 .향이 이르구르르이 되굴 아무 새 말이 웬도련님 내 아이고 저리 어머는 것을 메고 허고 오당(줄略)의 상로 들어 발 상상상( 風紗海) 장인 (針節) 손육 천(秋통)가 손수난리 선정현善 엉 운아 다 도련님 떨들어 제 벽드로 반반 수일 함 네 날아 내 나락다. 너                         "로 로로로 르르라
# 156/156 [==============================] - 42s 272ms/step - loss: 0.1771
# Epoch 38/60
# 156/156 [==============================] - ETA: 0s - loss: 0.1184
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "말듣소 어화 농부들 말들어 충청도 중복성은 주지가지가 열렸고 강릉땅 밤대"
# 말듣소 어화 농부들 말들어 충청도 중복성은 주지가지가 열렸고 강릉땅 밤대듣뜻 어사또을 들어보고 수정을 살도두아 보리 농부들어 우러에 춘향이 도 들이요다. 네 집어 네 기이 없는 보랑이야 어 낭골 수약인디 뚝어가 좋다 남았이라 오너 내 글을 피내 내 수에 없다니다 너는 오서 거지 날 사랑를 내어 소고 이라면 나는 무어 죽거로 나는 허고 도도님이 값른 기음 터로 찰슬내내 기중 월월 막 옥 맵주 안박 여여 불심면 되어 탄자(이懷) 너하나 다. 그에 바 보이라 "    "불, 내걸 노지 춘향이라 도련님 시고 손방님이 쭛느 남어     "춘향이 향향으니 빨(되나 이 분쌈 어보인디 "엇 추어 고 부르며 옥춘수 춘향하하 하하날 이든 울모지 나 마음이 되어 인머(만懷)이 되로 사또 바아 넣 날접 일은 있고 칭 수칭에 봉수수수(花巾兵)) 청게들다 다.장 성리 위도 못 거르면 봉이요없 내 된어
# 156/156 [==============================] - 43s 276ms/step - loss: 0.1184
# Epoch 39/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0961
# ----- Generating text after Epoch: 38
# ----- Generating with seed: "충충 들어오더니     "아 도련님 어쩌자고 이러시오 내 행차는 벌써 오"
# 충충 들어오더니     "아 도련님 어쩌자고 이러시오 내 행차는 벌써 오리더나 흉 떠경에 단써 가 팔는 이를 너아이고     "이 별 방인야 기리울르"     "워다 향엇이 우리 그근 지연는디 그때날 못 다겄다.     "그리게 어가 무냥이 집을 허여 말이고 말 간곳주 말니 남과 바라 저 날골아지 彩낸각이 해명 내 바내 까 띠이냐 내 떠이 어찌지!"     "아 하하다."     "만 !디 찾르가"     "허니라 저 것이요 내 말이요 오놈 이와 헐 이라."     "아 하계 썩식 어디 저소 말좀 여아 저 보느라."     "상가 본게 너짓 더더니 말을 찾나 나는 말이나."    "이 너내 회식 성자 줄 알르면 말을 바고 달느니도 말을 툭식 내가 다네 엄허여 말당도 호자 잡두 지아대황 늙딸아 우진 남 수피지 속금 울고 화사대이 값른 기찬 옵었으니 누리 찾나 거종 좋라없다 선편허
# 156/156 [==============================] - 43s 275ms/step - loss: 0.0961
# Epoch 40/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0797
# ----- Generating text after Epoch: 39
# ----- Generating with seed: ""     "들으라니 듣지요."     "기특하거든."     "기특하지"
# "     "들으라니 듣지요."     "기특하거든."     "기특하지요..     "거특듯 그리리? 우신이요 나려 어마는 기을 들어가 저주 도씨징 여라 저삼 아었더니 황추아 좋은 머음 떨고 박참 박가 들어 다여라!"     춘향이가 건가 놈을 놀더로 말을 여라 글장 춘향을 대르르 남 방쌈 저 !울울울미 아을 볼게 세을 바를 글일를 허고 내디 저갈 이시없 떡 들어요 불참 말이야 지도 말밑 마지지를 추차화 말이 허고 혼자죽 말이 도일 아니 저 눈 일 일 갈일야 야출여년 제비들여다고 저            들어가 아!! 그리 오틀노 장일로 형리 나라 저도 모고 내가 일주 가를 만허보니 마는를 나서 허으니 사마! 낭을 뜨여 섭디 박를 내어서 잇 한다 없다."     "서 자고 듣식 싫자 내가 번어 글단나는 말이 남모지나는 대날  일 보신가 웬일 요절 헐 었아니 깊 한 주씩 정디하야
# 156/156 [==============================] - 42s 271ms/step - loss: 0.0797
# Epoch 41/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0737
# ----- Generating text after Epoch: 40
# ----- Generating with seed: " 좋은 수가 있겠다. 어서 권주가나 불러봐라."         "진실로 "
#  좋은 수가 있겠다. 어서 권주가나 불러봐라."         "진실로 이틀마라 춘향에가 드여.     "예 옹식이 소 말이냐 오리 곡와 내 주고 나가가 한와 모단라 여려면 삼돼 나를 찾아 내 수긋 없다 너어 다고 죽어가 도도 님 물 아아고 너너자 춘향이 되거드로 소리사령 이 밤은 바위 듯 개리 알랑 저어 만줄이 구어주고 월목에 흘인(如夫)허고 춘향적같 주실(((版尾) 오따고 울고 울도비이 지섬지((中高待:::끄세  도련님마 마앞속라. 남한와 분황 남반 생 눈고 들어들고 수목이 없처 급정 바으으더 평굴운여 여 다르다 다리 모르!     "아이고 춘향이도 나나 우일 이몽시오 너 일어 어찌 보는 춘향단 저 딸 소리니 깊 간 주다니     "번에 춘향이 들어서며     "잘 알으니 비 것이요 잠와 모일 내 소리 다니 가라면 것단 모여 여면 저일 죽을 저어 삼상으로 나난 모모 절로 호
# 156/156 [==============================] - 43s 279ms/step - loss: 0.0737
# Epoch 42/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0683
# ----- Generating text after Epoch: 41
# ----- Generating with seed: "춘향이가 맛 좋은 술 내놓고 구너하니 어찌 먹어놨던지 사령들이 술이 담북"
# 춘향이가 맛 좋은 술 내놓고 구너하니 어찌 먹어놨던지 사령들이 술이 담북 좋 여리며      "춘향이 이 애 아아니 사또 단단 돈 못 소리 가랑팔다. . 어주신한     "이 자령이 썩 것이요. 너보느 춘향을 부자리 네소다. 놀불 곡경(게鑑白이 왔고 나는 들떼놓고 접 적적 어영고 줄 줄 부고 풍고 영 칭겠들 남문수단 문심거거 달진히 푸은 곳은 무화를 급를 구두 앞씨로 툭만 한월 구든 깊본날날 남원이라고 들어가자 춘향신중 중른 몽당댁와 다 거리 나리 울머갈경이 되어 서서 죽간 자 일녁지며 남 이 없고 다리 다여 간간의 도둘 남각 화 육 맵 미 공이야 아니 다고     "이리라 춘향이 들어운     "야 보저 춘향이 소리 너라 운심나 ."     "단 옥식이 썩 것이라. 네밤은 속고 부일 피고 저를 여아 여 두여라다."     "충방이 소지하소 아을 아대자 내어 아고 아아니도 하더
# 156/156 [==============================] - 42s 271ms/step - loss: 0.0683
# Epoch 43/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0576
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "는 중 처음이요 짝이 없는 일색이로구나 네 소문이 하 장하여 경향에 낭자"
# 는 중 처음이요 짝이 없는 일색이로구나 네 소문이 하 장하여 경향에 낭자를 돋소리 소회 한 사람이 웬다 고 저 저도 내렇를 주는시면 들이냐도 네 가 없고 줄도불에 이고 모모 죽었마마나 짝날각 여주 말을 바게 앉이 저 알실다 네 눈 이 정다 너너팔다. 중(중(흘頭) 내지지지 열너허나 주를 절어 며도 바은 일은 일은 좋부부옵불 남이 사령을 아니 다고 저가 도룡님 오 아기씨 떠도 말이     "하날 춘향이 비 듣감 그 소리 오소 그만 잡수(신婢)이 정어테다. 남춘문가 잠전(춘壯)) 석형 이면 오면 모를 붙은 일중중중 짝진사(연陵:色을 흑두 黑도 바년장((胡紗紗) 삼어 고 걸은 생 생떤줄 (문매) 춘향이 걸나 소었이 되어 지고 나나 오네!"     양이 놈로 듣어 싫더니만 저단 홍이다. 그리냐 말다 내 지거라. 사람이 틀전하고     "아이고 춘관이나 나가 무일 지는시면 너라! 네 방
# 156/156 [==============================] - 44s 280ms/step - loss: 0.0576
# Epoch 44/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0573
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "고,         "예라 이놈들! 가난한 양반 옷찢어진다. 기둥뿌리가 "
# 고,         "예라 이놈들! 가난한 양반 옷찢어진다. 기둥뿌리가 허니으니 빠가만 춘향이 되어사또 숙에 사여 죽어주고 잠비보고 장러주 걸은 각에 무전이 탐가지고 주주주로 장지져.     "춘향어가 소수궤려     "팔방형랜 치령하다 그 형쌈이 웬어사또 술이 추일이 들어다다 네        "오 충녁애 벌조하여 장 자식이 웬력리가 지고 내가 있고 나를 생각 저 저도도 있한다는 만주기(기)母)니 지상영걸(몸心心分)이 되겨 지쳐 제인에 성일일(일檢江) 정삼 기 가 줄 생 줄 모르느다."     "여 등황 그 그리 알 만일이나 말이나?"    "이렇 이 자식붓새갈 성이 너양이 허어어그 네 편어 한수인가 내잖되되 네 도 모르느니."     "
# 156/156 [==============================] - 42s 272ms/step - loss: 0.0573
# Epoch 45/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0508
# ----- Generating text after Epoch: 44
# ----- Generating with seed: " 침몰하여 은릭옥척(銀鱗玉尺)을 입에 물고 오락가락 노난 거동 평사낙안("
#  침몰하여 은릭옥척(銀鱗玉尺)을 입에 물고 오락가락 노난 거동 평사낙안(輾風落))이 대명 측에 십 수접(호徊) 상 장수(殊使) 낙 북들들어 선년가善("담赤山) 분교 연에 오개음( 편含귀귀 부목(龍別) 추육 방사(玄玄)가 소소장(장滿使)의 사목히 나여좋 마라(羽姜) 모려 사또(玄(::) 장두 뒤벅(또玄)가 북객장(客滿語)의 세목히 울여성단 추유((姜)) 이게 사연(玄::가 손소장( 水語백백 꾀공(목瑟) 추서 (공秋) 서 좋골(羽使) 장장장((玉使)) 사화(황長) 못서 나나 오도(罷檢)이 되거난사 골 절군(감(::) 곳창 목에에가 군군난((白팔水) 곳교발(相娼水)라 만앙무황 삼별봐로 삼을 춘아 거상하야 장장묘은 명 만 선고 건를 매소시면 정정이 좋는 내 저이 없캄느.     "아이고 춘향이 들어서고 여세시오."     넷떼를 자음사또 이수를 열수 부르리 ,     "소리 향이 찾리
# 156/156 [==============================] - 43s 276ms/step - loss: 0.0508
# Epoch 46/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0420
# ----- Generating text after Epoch: 45
# ----- Generating with seed: "나. 춘수는 만사택이라 허더니 물이 깊어서 이제온가. 무정허고 야속허데 "
# 나. 춘수는 만사택이라 허더니 물이 깊어서 이제온가. 무정허고 야속허데 한마는 천르르리 눈눈이 다리 울어 오시없이 아오구다 다별도 하기다 하네 그화 이부 죽어가 비며 지 수 모르니 남당각 기문하옵 일 일 골도 이녀허면 가가 죽다 죽었나     "도련님 춘향이 들은 그 몽지라도 말을 짓고 내가 이 다리 다소 그 분아니 떡당든가 해난 홍어 쫓골로 호를 접길 별든 황룡미깊 정을 뿐삼 묵씨      "춘향집이 썩거거랴 천문 생생 보 어주 다 춘향이요 정절노(디官硯) 우리 두夢 발(수넣자 가 수여 가고 황를 먹탕일 부음없  듯 상린 죽도 죽어난 부다. 오 장꼬 수냥 두부 사랑 마라     "이 날인 춘향이 부거오일     "워녀 향엇이 들 한일 말을 저르는디 어울고 하고 것이 칠소하"     "네 어사람은 춘향을 날은 수문 호에 저도 아주보니 형럴 죽고 나면 고 바라라.     "춘향이
# 156/156 [==============================] - 43s 276ms/step - loss: 0.0420
# Epoch 47/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0391
# ----- Generating text after Epoch: 46
# ----- Generating with seed: "듯 춘향을 부르고 자진헐게 그때여 춘향이난 내일 죽을 일을 생각허니 정신"
# 듯 춘향을 부르고 자진헐게 그때여 춘향이난 내일 죽을 일을 생각허니 정신를 기면 나니 새자 울접을 허거허는 너하형 꼬삭하여 은 현여 이리 울러 눌어 저 간양장 수문이 해네 지지서 불든 길소 구나오 일 한한 우버 울긋를 허거허.     "도련님 사정하랴 올을 웬구 보시로다. 너 딸 도련님이 자만를 좋어 나도 오전 삼아 마루 의 수심(없夫)가 상상 (족節) 추아이 울촉허고 가 바어 이요 한 분은 있고 나라면 부만이 못은 바든 만 눈골 없냥나. 지거거 기지(놈떠)가 저종하여 주은따리 어보있 춘향관 반 대치         일장부부 썩향을 들아오니     "이 옹서 이르더더니     "이기 기음에 갈며이 말이 있지라라.     "내 너의 너르 디 쥐락소"     "예 하이란 짚 이 있느?"     "사또?이 몽봉헌 시는디     "육 말이 춘향이 그일이 듣느 이가 이가 보달가. "
# 156/156 [==============================] - 42s 272ms/step - loss: 0.0391
# Epoch 48/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0369
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "년 늙은 년이 진외원족(眞外遠族) 하나없이 다만 독녀춘향하나 열쇠경 한 "
# 년 늙은 년이 진외원족(眞外遠族) 하나없이 다만 독녀춘향하나 열쇠경 한 소 로 져져 와만 데고 저루이 미셨알.     "허너 이 자식 새직 어요 소식 일어 그리나니 마마나 제 일이야 오느느 춘향각     "아이 사령이 아 운일이 .일 모모?"     "너 이렇게 태겄이 어 운단라. 도련님이 내게지고 어사또 행어 고게 세룡세 상졌에 여주, 장 한 천은 힘자으니 가거자 다다리 나는 앉도 죽룡으옵 .     "네 너슨 춘향이 그 섬너라 오 일이 웬일하여 이 얘 밑단 기방에다."         "향향모 이정 올구러     "말이 들어서 어 것이야 오느일이 고데휘이요 로 별이 웬내 보여라 . 말이 없다. 어 정이 만 수이은 새도도(이!衣) 말청 절어 소 상인 살 놓고고 갈 매고 누근 내 분풍시니 도련님 광시각을 사허는 도를 허어가 홀소를 살아 ,상하여 못 한 골씩 내리울여 영서 서서 못
# 156/156 [==============================] - 44s 280ms/step - loss: 0.0369
# Epoch 49/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0392
# ----- Generating text after Epoch: 48
# ----- Generating with seed: "지악의 범찮으면 버리난법 없는 줄 도련님은 모르시오. 내 딸 어린 춘향이"
# 지악의 범찮으면 버리난법 없는 줄 도련님은 모르시오. 내 딸 어린 춘향이! 도도님마는 세봉(翠夫)이 일느허느 어따일 네 구어 다고 일이 들어 물물거풍(羅差批)) 말로 타을 진니수 접접띠고 전러걸 사사차님 죽세대로 남남허고 오안오늘 적라 제한 글문이 없한 무월 들어 대황이 당는 기상 남아 네가 깊줄 들어 사또미이 불난올리 저 도 골 골 하하하야 내가 무서 하었진 그 마르나 버되 오시!     "아이 춘향이 아거고 운게 모르신 말을 가가 보겄니 저 하여 저 수 공은 당냥민야 집거낱 대수(紅睦)남 일 놀무는가 자었이 굳셔 일이 바고 어자거자 죽는 호삼 훤(기) 가 허나 그리 울머수벌 자키 연삼  가 없아 힘절하고 노진올 그두일 계는 박천 사또 같아 마황산산장 중단 충 좋아 우리 일일이야 부 기었었고 내 있어서 하는 올르하. 점씨에 따서를 정이 허니 벌상이 없든 울음     "아이고
# 156/156 [==============================] - 42s 271ms/step - loss: 0.0392
# Epoch 50/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0402
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "나. 호호거리고 나간다.       도련님 나귀나려 풀 띄끼고 사면경치를"
# 나. 호호거리고 나간다.       도련님 나귀나려 풀 띄끼고 사면경치를 내펴내 대다 허으냐?     "좌인을 술허거도 이옵없오 내 옥군로 구르리디 내 내 저씩 기방하여 내가 무서 서 그골없 풋절 듣라 저 것이 없다."     "하인 하너가 어탄겄을 이 있다다.     "     운로로 내가마여 어가자되 춘향한씨 간명동부들어사또 사닥을 들어서 춘향문 하고 천도 님황 유룩리 지든. 남네 사위을 나도 기만 든     "아따 춘향이 춘향운! 여 도식의 구르후에 방담허내 허려 데 어라 없이 도련님이 다면 되다 죽 낭골 없다 다여 오집으로 너 것이 없다니 너 말이 천다.     "하단 춘향이 도련님이 저 분 몰에 구르나 한 밑희 단다 디디 한허 마줄 깊어지 미주꺼다 제 불떤 수 죄녀났 가도요내 내 낭 그고 줄너었자 춘향이 놈기(如鑑)허니 춘향같이 다면 춘향이 있어 있어사또 선가 가 보
# 156/156 [==============================] - 44s 281ms/step - loss: 0.0402
# Epoch 51/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0352
# ----- Generating text after Epoch: 50
# ----- Generating with seed: "숨이나 살아날까 바랬더니마는 초록은 동색이요 가재는 게 편이라 ,양반은 "
# 숨이나 살아날까 바랬더니마는 초록은 동색이요 가재는 게 편이라 ,양반은 도도허고 이시고 이나 올이 무까밖지 또다 기명 묵씨기 쉬두한 앉걸걸을 들어있며 실 눈으 춘향모르르 춘향아가 거면 놓(다) 너리고 하는 올았서 있옵 이르도 나두다. 누당 골든 발러보고 내 뒤노도서 죽들어서 하는 들어서며 꼭를 여보,     "아따 춘향이 춘향의 백리야 형수 장라 못라허니         그리 오충애 아조로 춘향이 춘향하여 여리 절신을 보니 말이 저저 저아이 미등서서 행주산을 허는 삼은 나츰 황 좋산 일 알면 쌈당 줄이거마라."         "향실한     저오의 헐근의 좌조허고 장정 편일이라."     어사또 일매매며 이 자연 올각여니 말생 나서 내 부겄다. 사랑 낙단 고 기라 다디 내를 노겄다.     "이 놈이 너식 싫원이 말을 허고 나느냐?     "이 자식 너자 싫더니 가오도 것 일이고
# 156/156 [==============================] - 42s 273ms/step - loss: 0.0352
# Epoch 52/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0390
# ----- Generating text after Epoch: 51
# ----- Generating with seed: " 부인들게 붙드리여 집으로 돌아갈 제 저의 모친 울음소리 차차차 멀어지니"
#  부인들게 붙드리여 집으로 돌아갈 제 저의 모친 울음소리 차차차 멀어지니 칼방에 더으며 한진 바나서 아도고, 간다 도 하게 나너니다.     "나러 한 이식붓 물성에 말와을 지소리 벌을 모르나.     "하하하감 춘향을 들어사또 출하로 이리 나이 글지 두일이야 어     "  옥은 상 하하야 춘향을 백틀하여 도련님 남서서 돌어서 왔 보겄다."     "
# 156/156 [==============================] - 43s 276ms/step - loss: 0.0390
# Epoch 53/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0394
# ----- Generating text after Epoch: 52
# ----- Generating with seed: "청(海東靑:송골매) 보라매 모도다 쉬여넘는 동설령 고개 우리님이 왔다 허"
# 청(海東靑:송골매) 보라매 모도다 쉬여넘는 동설령 고개 우리님이 왔다 허고 나오나발 부추도 사위갓고 정정을 상아오니 있연항 하여 듯벽 목회세 상에 여삼 옥옥대산(白中中鞭) 여 별 연인을 가거드고 부무에 펼리 고 푸이요 오늘. 떨떨 측부 날점날.         옥장방상(썩暮暮) 그경왕왕하쌍 우동허아 광홍홍다 간사디 춘향 어사또 몸을 들어 노겄이냐 흉관 좀꼬 좋풍후 얻졌허오 누걸 대서 죽풍시고 귀인사 기은 여은 옥목밖를 꽉른 고 어내며     "나  계으니 부가겄다     "잘라 향 이 기수 성르르르 나찌 그다 있심나. 망 노식도 못 가르면 내놈 오시면 못도 말고 저 수 맵구. 아버고 서때! 그세(일갈)를 하고 사또 발으으 풍날 각길 제 영 걸 걸 헌 물일헌다. 아수난령(세天年次)로 허러 유 좌인 수 수어(느해紗) 띠려 기에 가 부인(幽含)헐 띠수난 殊안 한 벽((玄使) 모두 사또
# 156/156 [==============================] - 43s 277ms/step - loss: 0.0394
# Epoch 54/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0315
# ----- Generating text after Epoch: 53
# ----- Generating with seed: "   춘향이가 받어보니 서방님과 이별시에 드렸던 지가 찌든 옥지환이라 ."
#    춘향이가 받어보니 서방님과 이별시에 드렸던 지가 찌든 옥지환이라 .           "오문방 이온온 그 되었고 동하하다 나나 무일 기는 협이 다가 다가 오마라 나도 이길     "아이 옛고 나녀 그리 일이가 어가 단은 글장하야 용씨 너라 저심 다가 웬웬 바라 저 간도 없냥 되아 만거당마마라 너바방방(에年年次)허니 태인불를 늙인) 하고 위도 먹는 곳은 살자 좋수하옵(放진細一) 말로나 듯긴 장장(거道자) 사수(네殊) 허래 현~라목(知知使月)에 세에((娼娼)라요. 천라루루(天及高生))원지((開牛))이요 천월진자((南高主))원원(불민情) 하자루 내까산자 자유 춘향 가사람은 와둥과 제 일 걸고 풍자하고 이게 모서 죽리 되어 엄목 생각 깊어사또 양생에 사령이 말원 그를 옥황지긋 추산 년찬 뭍씨 옥연날 한 한적네 정충 담어 무는 마연날 남아이고 장충형장사또 눈심 사또 낙의 되어 사연
# 156/156 [==============================] - 42s 271ms/step - loss: 0.0315
# Epoch 55/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0439
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "   "네가 그렇게 기생점고를 허다가는 장장춘일이라도 못다 불러들일테니 "
#    "네가 그렇게 기생점고를 허다가는 장장춘일이라도 못다 불러들일테니 주주절이 왔신기장 !문히         "아이고 춘향이 들어서로 뜻 같어 알지리. 너복고 수수이 부거허여 소리 농르님     "야방견를 책창맥 모날라 형문신이 나하다     "아이 춘향이 아 듣는 그 보느 소일 단단이 되어 그라 오더니 내 불자 다든 울를 눌아거마 마씨를 기기이 놓어 나화 桑어     "아이고 춘향이 들어서 형인(의上)의 정은이 걸반 유으는 되꼬 어사디 쑥을 길고 오면 죽이나"     "백날 계충하였 춘향이 다결 일다 이고라. 태헌딸명 寤데 방어     "춘향이 춘향으니 천중되되다 나면 아니라 나못 어사또 이수 못 춘향네 남를 길루 섭룩는 마는 한 사자.     "네날 오더 춘향이 소리하여 왔(럽金나나는 허시난 것은 수인( 思思사또 코고목고 말이 걸고 있성느이 알짝 무행 좋은 청연이 웬용허고
# 156/156 [==============================] - 43s 278ms/step - loss: 0.0439
# Epoch 56/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0415
# ----- Generating text after Epoch: 55
# ----- Generating with seed: "슨 정황이 있다고 날 찾아왔어."     어사또 이른 말,     "내가"
# 슨 정황이 있다고 날 찾아왔어."     어사또 이른 말,     "내가 아엇 그른가 어  일이 있다니 너와 욕모지나 "잖허요. 기가 만고 읽이 없어마는 부중이 흘라하고 칼리 말웃을 나도시여 간인정으로 지니 놓고 좋츰 수르리 부어가 고찌 모르 구나님 탐세를 물담짓고 지선상장 상녕을 과실허여 어사 농전을 부도련이 춘향아 전달(정撰)허고 춘향은 나면 넣의 바순바고 자프 적각 춘향하시 봉관헌면 춘향이 절로 올촉 신 글골 연돌 조여 삼목 네 대줄을 불니허니 내별기생 요난 것이     "이 야 이 애 럴락소. 너리 너"     "네 요식때 썩는라      "아 대저이 썩 섬너라 오와 그모"     "네 요식 썩향아 어 운원 그 몽느나니 말니 낙리 게심네야 잠씨 허고 허겄 좋이 벌지 만참 삼심 네 날 맵 있니 한디 단시시마" 그 중상에 왔는 것이 칠으하야 내라 낭단 죽었으로 그리 허고 나
# 156/156 [==============================] - 42s 269ms/step - loss: 0.0415
# Epoch 57/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0343
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "가!"     또 어떤 기생이 들어서며 추세를 쫓아 부른다고     "아"
# 가!"     또 어떤 기생이 들어서며 추세를 쫓아 부른다고     "아이고 여움 !"님 얼는 차게 내가 도소치"     "틈 이렇 어사람이 춘향이가 그고 정정이 이르리다 네 갈이 웬참이 칠 흔르면 저리 도련님     "아이 옛찌 춘향이 도련님은 저     "이라 향단이 우리허고 세 한이 주력 두리가다 내 한 이 다 받 마라면 춘향이 !리하여 방 때경 깊 하음비 부가지고 내 것이 차니 그를 바든 내 가 없구. 깊 죽으니 저 히 주에 줄불불야 하오시면 내서 내일 마라 마는 ! 수집봉 나는 저     "춘향집 상밤리 몽은 단을 대리 청구하나 너라 남삼님 가시다 용씨 하여 헐지지마미 풀낸사랑 마음을 들어 넘장을 못 구르네 앞을 번고 서 수에나 내 정에 정인 내 분뜰네 안고 오시더더 너는 저래 거가라 가 보르고 것을 가시겠 열을 생삼 저가가 나는 고 글감로 내를 모고 간당도 상렀 탄거
# 156/156 [==============================] - 44s 281ms/step - loss: 0.0343
# Epoch 58/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0315
# ----- Generating text after Epoch: 57
# ----- Generating with seed: "낭군 수절헌디 그게 무삼 죄가 되어 엄치형장이 웬일이냐 이것이 모도다 내"
# 낭군 수절헌디 그게 무삼 죄가 되어 엄치형장이 웬일이냐 이것이 모도다 내대탓뜻 불가대 가 어 골을 죽시느니 !월 죽고 드니 부 마음허고 저충  여     "춘향집 향밤 올른 얼몽 좀 사랑 나가 저 물단시다."     "내가!"     "오럼!헐 상중 들어가 갈글년장 자리 대우리보 여을 모르나나 하중 못가 나면 말을 허여라니 옥군에 만인져)하다. 날 술으니 나들 기가 보는 모르난디 어데 철은 가시진 말은 허고 나도 오든 불지거로 남비사령 울고 고, 글은 자자 일어 여여 물장을 불어가는 목는 사람 못발거라 군추 년부 잡씨날 뉘간 허여 풍미수산 값옵상사 방계방융 일자 행행 어어 주시난 한 사람봉 못 저는 저로 바를 간거시마 너는 오모 좋종히 일은 음월 잡었날 미씨마다 쏜신각리 대고 코 수산윤 듯 하르소 춘향집을 건고서 말이 고허으니 불추한 꼬구허고 이로자취 아로다는 야야 말을 들어주
# 156/156 [==============================] - 42s 271ms/step - loss: 0.0315
# Epoch 59/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0372
# ----- Generating text after Epoch: 58
# ----- Generating with seed: "도 국운이 불행허여 도적이 강성하면 적하의 무릎꿇어 두 임군을 섬기랴오 "
# 도 국운이 불행허여 도적이 강성하면 적하의 무릎꿇어 두 임군을 섬기랴오 오오내  달 대골 벌이 앉혀 두가 마줄 내 대이 없다."     "충충은 가지" 광신을 이른게 장겄고 알느 척이 있소 내 두아 없다 가를 둘여 보시으면 너는 오차산이 점되허다 저 도 골씩 우음하야 영부 전서 나면 앉이 바지 벌어 다시니 나는 도도 잡오더니 너씨 좀서 거종 잊이 다 앉어 다 다리니 떡 지어주 정 사랑 일 두랑지야 내뼈 만리 못 맺이냐 내가 무양 이 곳아니며     "네 놈하고 상상을 여른 일이 있고 보아 도 못떤고 구시니 한 것 써 틀 두이냐 한 간에 번냥내 부비를 날은 고도 만렇 내 없이 없다."     "충 이 허지고 태울고 운다 오장 지고 쉰이라."     "아가게 네가 사람님님을 자른 그리고 무을 알어 해도 만이 저가 없소소.     "백이별 춘향을 들어 고 발신 소도 아고 잘아니 마고
# 156/156 [==============================] - 43s 277ms/step - loss: 0.0372
# Epoch 60/60
# 156/156 [==============================] - ETA: 0s - loss: 0.0272
# ----- Generating text after Epoch: 59
# ----- Generating with seed: ") 모수 통행전(通行廛) 쌍문초(雙紋 ) 겹동옷에 청중추막(靑中赤莫)에 "
# ) 모수 통행전(通行廛) 쌍문초(雙紋 ) 겹동옷에 청중추막(靑中赤莫)에 세중 물혀 제 오음(幽春含띠띠 띠네 네 큰 걸리져 봉지매매 내 걸무 상사비건 말옵묘 하아 남았 비전지 . 알 봉소서 아 네 사람을 불리하는 노비도도 비게 내미 혼츰 윤연으로 그를 허고 민러 나는 줄     "방방 옛고 찾희 더더니 나오간다 고 일쌈는 참써허니 칠담 내일 잡어서 시릴 내 상을 살르니 부 만 있고 내약히 시는 간도 만 날 맵일이 웬를를 주시거내 너마마오."     호째을 바음을 놈이 그려런     "오냐?     "중방얘 상중마?"     "내 자사람 비조러라 대(의 나는 거리 이로다. 태태 낙방님을 놀어다 저두를 살르드.     "좌인은 금하하랴"     이렇자 춘향이요 우리 일일이 있는 것었고 저하여 저 도 잘 공린 야디 야두시마라 너라 오리을 아니고 사또 놈부 로란드며 마리가 기서 허게 서
# 156/156 [==============================] - 43s 275ms/step - loss: 0.0272

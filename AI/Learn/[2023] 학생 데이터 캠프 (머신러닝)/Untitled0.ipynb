# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], 28 * 28).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28 * 28).astype('float32') / 255
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# Create the neural network model
model = Sequential()
model.add(Dense(256, input_dim=28 * 28, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_split=0.1, epochs=10, batch_size=200, verbose=1)

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy:.4f}')

# Load the first picture file in the test dataset and display it
first_image = X_test[0].reshape(28, 28)
plt.imshow(first_image, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Epoch 1/10
# 270/270 [==============================] - 8s 4ms/step - loss: 0.3425 - accuracy: 0.9014 - val_loss: 0.1293 - val_accuracy: 0.9613
# Epoch 2/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1270 - accuracy: 0.9625 - val_loss: 0.0905 - val_accuracy: 0.9743
# Epoch 3/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0845 - accuracy: 0.9746 - val_loss: 0.0954 - val_accuracy: 0.9717
# Epoch 4/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0584 - accuracy: 0.9817 - val_loss: 0.0795 - val_accuracy: 0.9773
# Epoch 5/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0431 - accuracy: 0.9866 - val_loss: 0.0803 - val_accuracy: 0.9773
# Epoch 6/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0339 - accuracy: 0.9888 - val_loss: 0.0799 - val_accuracy: 0.9788
# Epoch 7/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0293 - accuracy: 0.9907 - val_loss: 0.0898 - val_accuracy: 0.9758
# Epoch 8/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.0709 - val_accuracy: 0.9830
# Epoch 9/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.0786 - val_accuracy: 0.9813
# Epoch 10/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0786 - val_accuracy: 0.9818
# Test loss: 0.0867, Test accuracy: 0.9783

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], 28 * 28).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28 * 28).astype('float32') / 255
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# Create the neural network model
model = Sequential()
model.add(Dense(256, input_dim=28 * 28, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_split=0.1, epochs=10, batch_size=200, verbose=1)

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy:.4f}')

# Load the first picture file in the test dataset and display it
first_image = X_test[0].reshape(28, 28)
plt.imshow(first_image, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Epoch 1/10
# 270/270 [==============================] - 2s 4ms/step - loss: 0.3478 - accuracy: 0.8984 - val_loss: 0.1373 - val_accuracy: 0.9583
# Epoch 2/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1222 - accuracy: 0.9634 - val_loss: 0.1218 - val_accuracy: 0.9607
# Epoch 3/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0808 - accuracy: 0.9761 - val_loss: 0.0829 - val_accuracy: 0.9748
# Epoch 4/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0581 - accuracy: 0.9823 - val_loss: 0.0813 - val_accuracy: 0.9763
# Epoch 5/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0445 - accuracy: 0.9866 - val_loss: 0.0865 - val_accuracy: 0.9747
# Epoch 6/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.0806 - val_accuracy: 0.9783
# Epoch 7/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.0863 - val_accuracy: 0.9782
# Epoch 8/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.0861 - val_accuracy: 0.9792
# Epoch 9/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0790 - val_accuracy: 0.9815
# Epoch 10/10
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.1025 - val_accuracy: 0.9778
# Test loss: 0.0774, Test accuracy: 0.9795

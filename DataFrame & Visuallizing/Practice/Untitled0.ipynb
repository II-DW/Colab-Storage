# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_csv('인천광역시_하루 평균 근로시간.csv', encoding='cp949')

# %%
df
# Out:
#           /        특성별(2)  1-3시간 미만 (퍼센트)  3-5시간 미만 (퍼센트)  5-7시간 미만 (퍼센트)  \
# 0       군구별            중구             0.1             3.9             5.0
# 1       군구별            동구             3.5             7.9             8.2
# 2       군구별          미추홀구             NaN             2.0             5.2
# 3       군구별           연수구             2.3             3.1             3.5
# 4       군구별           남동구             0.2             3.0             5.4
# 5       군구별           부평구             1.2             5.1             4.7
# 6       군구별           계양구             0.4             3.2             5.2
# 7       군구별            서구             1.9             4.8             5.0
# 8       군구별           강화군             5.0             8.6             6.0
# 9       군구별           옹진군             1.3            13.5            13.9
# 10       성별            남자             0.9             2.4             3.2
# 11       성별            여자             1.5             6.1             7.7
# ...

# %%
df2 = pd.DataFrame(df.iloc[10] + df.iloc[11])
df2
# Out:
#                      0
# /                 성별성별
# 특성별(2)            남자여자
# 1-3시간 미만 (퍼센트)     2.4
# 3-5시간 미만 (퍼센트)     8.5
# 5-7시간 미만 (퍼센트)    10.9
# 7-9시간 미만 (퍼센트)   127.4
# 9-12시간 미만 (퍼센트)   44.0
# 12시간 이상 (퍼센트)      6.6
# 평균 (시간)           16.2

# %%
df2 = df2[2:]
df2 = df2[:-1]
df2
# Out:
#                      0
# 1-3시간 미만 (퍼센트)     2.4
# 3-5시간 미만 (퍼센트)     8.5
# 5-7시간 미만 (퍼센트)    10.9
# 7-9시간 미만 (퍼센트)   127.4
# 9-12시간 미만 (퍼센트)   44.0
# 12시간 이상 (퍼센트)      6.6

# %%
plt.pie(df2[0].astype(float), labels = df2.index, autopct = '%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7a0fefae2c80>,
# ...
#  [Text(1.0992168545444518, 0.04150068295102541, '1-3시간 미만 (퍼센트)'),
#   Text(1.0760342277128485, 0.22836449108916682, '3-5시간 미만 (퍼센트)'),
#   Text(0.9577742913604547, 0.5409883610660946, '5-7시간 미만 (퍼센트)'),
#   Text(-0.9891278973129062, 0.4812753918053043, '7-9시간 미만 (퍼센트)'),
#   Text(0.6842921125214554, -0.8612457864866011, '9-12시간 미만 (퍼센트)'),
#   Text(1.0940820582312005, -0.1139493302155844, '12시간 이상 (퍼센트)')],
#  [Text(0.5995728297515192, 0.022636736155104763, '1.20'),
#   Text(0.5869277605706446, 0.12456244968500006, '4.25'),
#   Text(0.5224223407420661, 0.2950845605815061, '5.46'),
#   Text(-0.5395243076252215, 0.2625138500756205, '63.76'),
#   Text(0.3732502431935211, -0.46977042899269145, '22.02'),
#   Text(0.596772031762473, -0.06215418011759148, '3.30')])

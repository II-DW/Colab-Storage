# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x, y) :
  return 3 * x * x  + 3 * y * y + x * y * y + 7 * x + 7 * y + 10

# %%
def g(x, y) :
  return 6 * x + y * y + 7

# %%
def h(x, y) :
  return 6 * y + 2 * x * y + 7

# %%
import numpy as np

fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(-4, 4, 0.1)
y = np.arange(-4, 4, 0.1)

xx, yy = np.meshgrid(x, y)
temp = np.zeros((len(x), len(y)))
for i in range (len(x)) :
  for j in range (len(y)) :
    temp[i, j] = f(x[i], y[j])

y_zeros = np.zeros(len(y))

ax.plot_surface(xx, yy, temp, rstride = 1, cstride = 1, alpha = 1, color = 'blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
plt.show()

# %%
import numpy as np

fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(-4, 4, 0.1)
y = np.arange(-4, 4, 0.1)

xx, yy = np.meshgrid(x, y)
temp = np.zeros((len(x), len(y)))
for i in range (len(x)) :
  for j in range (len(y)) :
    temp[i, j] = f(x[i], y[j])

y_zeros = np.zeros(len(y))

ax.plot_surface(xx, yy, temp, rstride = 1, cstride = 1, alpha = 0.1, color = 'blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.plot(x, y_zeros, f(x,0), color = 'red')
plt.show()

# %%
import numpy as np

fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(-4, 4, 0.1)
y = np.arange(-4, 4, 0.1)

xx, yy = np.meshgrid(x, y)
temp = np.zeros((len(x), len(y)))
for i in range (len(x)) :
  for j in range (len(y)) :
    temp[i, j] = f(x[i], y[j])

y_zeros = np.zeros(len(y))

ax.plot_surface(xx, yy, temp, rstride = 1, cstride = 1, alpha = 0.1, color = 'blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.plot(x, y_zeros, f(x,0), color = 'red')
ax.view_init(0, -90)
plt.show()

# %%
import numpy as np

fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(-4, 4, 0.1)
y = np.arange(-4, 4, 0.1)

xx, yy = np.meshgrid(x, y)
temp = np.zeros((len(x), len(y)))
for i in range (len(x)) :
  for j in range (len(y)) :
    temp[i, j] = f(x[i], y[j])

x_zeros = np.zeros(len(x))
y_zeros = np.zeros(len(y))

ax.plot_surface(xx, yy, temp, rstride = 1, cstride = 1, alpha = 0.1, color = 'blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')

ax.plot(x, y_zeros, f(x,0), color = 'red')
ax.plot(x_zeros, y, f(0,x), color = 'black')
plt.show()

# %%
import numpy as np

fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(-4, 4, 0.1)
y = np.arange(-4, 4, 0.1)

xx, yy = np.meshgrid(x, y)
temp = np.zeros((len(x), len(y)))
for i in range (len(x)) :
  for j in range (len(y)) :
    temp[i, j] = f(x[i], y[j])

y_zeros = np.zeros(len(y))
x_zeros = np.zeros(len(x))

ax.plot_surface(xx, yy, temp, rstride = 1, cstride = 1, alpha = 0.1, color = 'blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.plot(x, y_zeros, f(x,0), color = 'red')
ax.plot(x, y_zeros, g(0,0) * x + f(0, 0), color = 'black')
ax.plot(x_zeros, y, f(0,x), color = 'red')
ax.plot(x_zeros, y, g(0,0) * y + f(0, 0), color = 'black')
ax.view_init(0, 0)
plt.show()

# %%
x = [1, 1, 2, 3, 4, 6, 9, 9, 11, 13, 15, 16, 17, 19, 20, 22]
y = [50, 51, 49, 46, 43, 42, 47, 45, 35, 39, 39, 38, 38, 37, 36, 31]

# %%
plt.scatter(x, y, color='red')
plt.xlim([min(x)- 5, max(x) + 5])
plt.ylim([0, max(y) + 5])
# Out:
# (0.0, 56.0)

# %%
def MSEw (x, y, w,b) :
  return (2/len(x)) * sum((-y + w * x + b) * x)

def MSEb (x, y, w,b) :
  return (2/len(x)) * sum((-y + w * x + b))

# %%
import numpy as np

def gradient(x_data, y_data, w, b,lr) :
  x_data = np.array(x_data)
  y_data = np.array(y_data)

  #현재 오차 그래프에서 w의 미분계수
  w_gradient = MSEw(x_data, y_data, w, b)

  #현재 오차 그래프에서 b의 미분계수
  b_gradient = MSEb(x_data, y_data, w, b)

  w = w - lr * w_gradient
  b = b - lr * b_gradient

  return w, b

# %%
epochs = 6001  #학습 횟수
lr = 0.0025   #학습률
w = 0       #최초 기울기 설정
b = 0       #최초 y절편 설정

List = []

#학습 횟수 epoch만큼 경사 하강법 실행
for i in range(epochs):
  w, b = gradient(x, y, w, b, lr)

  # 학습 횟수가 1000번째일 때마다 기울기와 y절편을 출력
  if i % 10 == 0 :
    print('학습 횟수', i, '기울기', w, 'y절편', b)
    List.append([w, b])
# Out:
# 학습 횟수 0 기울기 2.0078125 y절편 0.208125
# 학습 횟수 10 기울기 2.476642753148775 y절편 0.9806317534371752
# 학습 횟수 20 기울기 2.4283504576814448 y절편 1.7076501124824761
# 학습 횟수 30 기울기 2.3807836496097288 y절편 2.423745598248552
# 학습 횟수 40 기울기 2.3339314947552814 y절편 3.1290823225268154
# 학습 횟수 50 기울기 2.2877832560255524 y절편 3.8238219270969633
# 학습 횟수 60 기울기 2.2423283576442055 y절편 4.508123625200335
# 학습 횟수 70 기울기 2.1975563827274778 y절편 5.182144238026758
# 학습 횟수 80 기울기 2.1534570708969474 y절편 5.84603823065321
# 학습 횟수 90 기울기 2.1100203159281654 y절편 6.4999577474425205
# 학습 횟수 100 기울기 2.067236163434616 y절편 7.144052646910254
# 학습 횟수 110 기울기 2.0250948085864717 y절편 7.778470536067727
# 학습 횟수 120 기울기 1.9835865938636277 y절편 8.403356804249059
# 학습 횟수 130 기울기 1.9427020068424863 y절편 9.018854656430003
# 학습 횟수 140 기울기 1.902431678016001 y절편 9.625105146046176
# 학습 횟수 150 기울기 1.8627663786464694 y절편 10.222247207318228
# 학습 횟수 160 기울기 1.8236970186505852 y절편 10.810417687091352
# 학습 횟수 170 기울기 1.7852146445162689 y절편 11.389751376196426
# 학습 횟수 180 기울기 1.7473104372507926 y절편 11.960381040339986
# 학습 횟수 190 기울기 1.709975710359735 y절편 12.522437450530097
# 학습 횟수 200 기울기 1.6732019078563014 y절편 13.076049413045103
# 학습 횟수 210 기울기 1.6369806023005493 y절편 13.621343798952116
# 학습 횟수 220 기울기 1.6013034928680763 y절편 14.158445573182016
# 학습 횟수 230 기울기 1.5661624034477217 y절편 14.68747782316762
# 학습 횟수 240 기울기 1.5315492807678517 y절편 15.208561787051591
# 학습 횟수 250 기울기 1.4974561925507919 y절편 15.721816881470543
# 학습 횟수 260 기울기 1.4638753256949908 y절편 16.22736072892171
# 학습 횟수 270 기울기 1.4307989844844935 y절편 16.72530918471846
# 학습 횟수 280 기울기 1.3982195888253182 y절편 17.215776363540794
# 학습 횟수 290 기울기 1.3661296725083278 y절편 17.698874665587002
# 학습 횟수 300 기울기 1.3345218814982003 y절편 18.174714802332364
# 학습 횟수 310 기울기 1.3033889722481093 y절편 18.64340582190085
# 학습 횟수 320 기울기 1.2727238100397202 y절편 19.10505513405567
# 학습 횟수 330 기울기 1.2425193673481316 y절편 19.559768534814296
# 학습 횟수 340 기울기 1.2127687222313779 y절편 20.007650230693738
# 학습 횟수 350 기울기 1.1834650567441323 y절편 20.448802862591474
# 학습 횟수 360 기울기 1.1546016553752372 y절편 20.883327529307685
# 학습 횟수 370 기울기 1.1261719035087168 y절편 21.311323810713976
# 학습 횟수 380 기울기 1.0981692859079042 y절편 21.732889790574113
# 학습 횟수 390 기울기 1.0705873852223493 y절편 22.148122079021803
# 학습 횟수 400 기울기 1.0434198805171557 y절편 22.55711583470082
# 학습 횟수 410 기울기 1.0166605458244147 y절편 22.9599647865725
# 학습 횟수 420 기울기 0.990303248716401 y절편 23.356761255395543
# 학습 횟수 430 기울기 0.9643419489002084 y절편 23.747596174883157
# 학습 횟수 440 기울기 0.9387706968334956 y절편 24.132559112542292
# 학습 횟수 450 기울기 0.9135836323610343 y절편 24.511738290199794
# 학습 횟수 460 기울기 0.888774983371736 y절편 24.885220604220187
# 학습 횟수 470 기울기 0.8643390644758626 y절편 25.253091645419662
# 학습 횟수 480 기울기 0.8402702757021058 y절편 25.615435718680907
# 학습 횟수 490 기울기 0.8165631012142434 y절편 25.97233586227323
# 학습 횟수 500 기울기 0.793212108047077 y절편 26.32387386688242
# 학습 횟수 510 기울기 0.7702119448613626 y절편 26.67013029435466
# 학습 횟수 520 기울기 0.7475573407174443 y절편 27.011184496158897
# 학습 횟수 530 기울기 0.7252431038673154 y절편 27.347114631571767
# 학습 횟수 540 기울기 0.7032641205648281 y절편 27.67799768558932
# 학습 횟수 550 기울기 0.6816153538937765 y절편 28.003909486569686
# 학습 횟수 560 기울기 0.6602918426135893 y절편 28.324924723610593
# 학습 횟수 570 기울기 0.639288700022364 y절편 28.641116963665862
# 학습 횟수 580 기울기 0.6186011128369818 y절편 28.952558668404727
# 학습 횟수 590 기울기 0.5982243400900514 y절편 29.259321210817827
# 학습 횟수 600 기울기 0.5781537120434199 y절편 29.561474891573763
# 학습 횟수 610 기울기 0.558384629118014 y절편 29.859088955129852
# 학습 횟수 620 기울기 0.5389125608397529 y절편 30.152231605600868
# 학습 횟수 630 기울기 0.5197330448013046 y절편 30.440970022389344
# 학습 횟수 640 기울기 0.5008416856394328 y절편 30.72537037558108
# 학습 횟수 650 기울기 0.4822341540277179 y절편 31.00549784110928
# 학습 횟수 660 기울기 0.4639061856844031 y절편 31.28141661569094
# 학습 횟수 670 기울기 0.445853580395152 y절편 31.55318993153876
# 학습 횟수 680 기울기 0.4280722010504872 y절편 31.820880070852052
# 학습 횟수 690 기울기 0.41055797269768846 y절편 32.084548380089956
# 학습 횟수 700 기울기 0.39330688160694 y절편 32.34425528403013
# 학습 횟수 710 기울기 0.37631497435150263 y절편 32.60006029961636
# 학습 횟수 720 기울기 0.3595783569017099 y절편 32.852022049597956
# 학습 횟수 730 기울기 0.3430931937325741 y절편 33.10019827596435
# 학습 횟수 740 기울기 0.3268557069448004 y절편 33.34464585317782
# 학습 횟수 750 기울기 0.31086217539900657 y절편 33.585420801207356
# 학습 횟수 760 기울기 0.2951089338629528 y절편 33.822578298366736
# 학습 횟수 770 기울기 0.27959237217157756 y절편 34.05617269395977
# 학습 횟수 780 기울기 0.2643089343996615 y절편 34.286257520735475
# 학습 횟수 790 기울기 0.24925511804691355 y절편 34.51288550715616
# 학습 횟수 800 기울기 0.23442747323530863 y절편 34.73610858948119
# 학습 횟수 810 기울기 0.21982260191847394 y절편 34.95597792366922
# 학습 횟수 820 기울기 0.2054371571029664 y절편 35.17254389710155
# 학습 횟수 830 기울기 0.1912678420812405 y절편 35.385856140129405
# 학습 횟수 840 기울기 0.1773114096761419 y절편 35.59596353744774
# 학습 횟수 850 기울기 0.16356466149675222 y절편 35.80291423929808
# 학습 횟수 860 기울기 0.15002444720541905 y절편 36.00675567250311
# 학습 횟수 870 기울기 0.13668766379579086 y절편 36.20753455133546
# 학습 횟수 880 기울기 0.12355125488170322 y절편 36.40529688822322
# 학습 횟수 890 기울기 0.11061220999674619 y절편 36.600088004294555
# 학습 횟수 900 기울기 0.09786756390435847 y절편 36.79195253976399
# 학습 횟수 910 기울기 0.08531439591828453 y절편 36.98093446416254
# 학습 횟수 920 기울기 0.07294982923324204 y절편 37.1670770864142
# 학습 횟수 930 기울기 0.0607710302656467 y절편 37.35042306476106
# 학습 횟수 940 기울기 0.04877520800423677 y절편 37.53101441653928
# 학습 횟수 950 기울기 0.036959613370463766 y절편 37.70889252780814
# 학습 횟수 960 기울기 0.025321538588481796 y절편 37.88409816283454
# 학습 횟수 970 기울기 0.013858316564610977 y절편 38.05667147343487
# 학습 횟수 980 기울기 0.002567320276117037 y절편 38.226652008176664
# 학습 횟수 990 기울기 -0.008554037830818232 y절편 38.39407872144184
# 학습 횟수 1000 기울기 -0.019508306434089448 y절편 38.558989982353935
# 학습 횟수 1010 기울기 -0.030297995919743817 y절편 38.721423583571074
# 학습 횟수 1020 기울기 -0.04092557895729034 y절편 38.881416749947
# 학습 횟수 1030 기울기 -0.05139349106635682 y절편 39.039006147061805
# 학습 횟수 1040 기울기 -0.061704131174837376 y절편 39.194227889624564
# 학습 횟수 1050 기울기 -0.07185986216865534 y절편 39.34711754974979
# 학습 횟수 1060 기울기 -0.08186301143326459 y절편 39.497710165109424
# 학습 횟수 1070 기울기 -0.09171587138701513 y절편 39.64604024696245
# 학습 횟수 1080 기울기 -0.10142070000650627 y절편 39.7921417880638
# 학습 횟수 1090 기울기 -0.11097972134404613 y절편 39.93604827045447
# 학습 횟수 1100 기울기 -0.12039512603733771 y절편 40.077792673134596
# 학습 횟수 1110 기울기 -0.12966907181150455 y절편 40.21740747962122
# 학습 횟수 1120 기울기 -0.1388036839735777 y절편 40.35492468539255
# 학습 횟수 1130 기울기 -0.14780105589955253 y절편 40.490375805220346
# 학습 횟수 1140 기울기 -0.1566632495141258 y절편 40.62379188039217
# 학습 횟수 1150 기울기 -0.16539229576322467 y절편 40.75520348582504
# 학습 횟수 1160 기울기 -0.1739901950794386 y절편 40.884640737072345
# 학습 횟수 1170 기울기 -0.1824589178404613 y절편 41.0121332972254
# 학습 횟수 1180 기울기 -0.1908004048206382 y절편 41.137710383711294
# 학습 횟수 1190 기울기 -0.19901656763573194 y절편 41.26140077498868
# 학습 횟수 1200 기울기 -0.2071092891810097 y절편 41.38323281714288
# 학습 횟수 1210 기울기 -0.215080424062744 y절편 41.503234430382
# 학습 횟수 1220 기울기 -0.2229317990232319 y절편 41.62143311543533
# 학습 횟수 1230 기울기 -0.23066521335943085 y절편 41.73785595985576
# 학습 횟수 1240 기울기 -0.23828243933530133 y절편 41.85252964422735
# 학습 횟수 1250 기울기 -0.24578522258795688 y절편 41.965480448279756
# 학습 횟수 1260 기울기 -0.2531752825277103 y절편 42.07673425691074
# 학습 횟수 1270 기울기 -0.2604543127321092 y절편 42.186316566118144
# 학습 횟수 1280 기울기 -0.2676239813340573 y절편 42.294252488842915
# 학습 횟수 1290 기울기 -0.27468593140409414 y절편 42.40056676072413
# 학습 횟수 1300 기울기 -0.2816417813269409 y절편 42.50528374576769
# 학습 횟수 1310 기울기 -0.28849312517238174 y절편 42.608427441929805
# 학습 횟수 1320 기울기 -0.2952415330605813 y절편 42.71002148661662
# 학습 횟수 1330 기울기 -0.3018885515219023 y절편 42.810089162101136
# 학습 횟수 1340 기울기 -0.3084357038513294 y절편 42.90865340085889
# 학습 횟수 1350 기울기 -0.3148844904575582 y절편 43.00573679082329
# 학습 횟수 1360 기울기 -0.32123638920684333 y절편 43.10136158056213
# 학습 횟수 1370 기울기 -0.32749285576168435 y절편 43.195549684376296
# 학습 횟수 1380 기울기 -0.3336553239144164 y절편 43.288322687321845
# 학습 횟수 1390 기울기 -0.33972520591579114 y절편 43.379701850156636
# 학습 횟수 1400 기울기 -0.34570389279862346 y절편 43.469708114212644
# 학습 횟수 1410 기울기 -0.3515927546965736 y절편 43.558362106195105
# 학습 횟수 1420 기울기 -0.35739314115814186 y절편 43.64568414290954
# 학습 횟수 1430 기울기 -0.3631063814559401 y절편 43.73169423591769
# 학습 횟수 1440 기울기 -0.3687337848913251 y절편 43.81641209612365
# 학습 횟수 1450 기울기 -0.37427664109444825 y절편 43.89985713829091
# 학습 횟수 1460 기울기 -0.37973622031979964 y절편 43.982048485491696
# 학습 횟수 1470 기울기 -0.3851137737373126 y절편 44.063004973489384
# 학습 횟수 1480 기울기 -0.39041053371909357 y절편 44.142745155055074
# 학습 횟수 1490 기울기 -0.3956277141218442 y절편 44.22128730421934
# 학습 횟수 1500 기울기 -0.400766510565043 y절편 44.298649420460066
# 학습 횟수 1510 기울기 -0.4058281007049398 y절편 44.3748492328274
# 학습 횟수 1520 기울기 -0.41081364450444446 y절편 44.44990420400669
# 학습 횟수 1530 기울기 -0.4157242844989506 y절편 44.52383153432042
# 학습 횟수 1540 기울기 -0.42056114605817385 y절편 44.59664816567001
# 학습 횟수 1550 기울기 -0.4253253376440488 y절편 44.66837078541833
# 학습 횟수 1560 기울기 -0.4300179510647581 y절편 44.73901583021403
# 학습 횟수 1570 기울기 -0.4346400617249396 y절편 44.80859948975823
# 학습 횟수 1580 기울기 -0.43919272887213756 y절편 44.87713771051477
# 학습 횟수 1590 기울기 -0.4436769958395504 y절편 44.94464619936465
# 학습 횟수 1600 기울기 -0.44809389028512975 y절편 45.01114042720553
# 학습 횟수 1610 기울기 -0.45244442442708793 y절편 45.07663563249721
# 학습 횟수 1620 기울기 -0.45672959527587065 y절편 45.14114682475385
# 학습 횟수 1630 기울기 -0.4609503848626378 y절편 45.20468878798364
# 학습 횟수 1640 기울기 -0.4651077604643193 y절편 45.26727608407694
# 학습 횟수 1650 기울기 -0.46920267482528266 y절편 45.328923056143324
# 학습 횟수 1660 기울기 -0.47323606637567317 y절편 45.38964383179862
# 학습 횟수 1670 기울기 -0.47720885944647606 y절편 45.449452326402564
# 학습 횟수 1680 기울기 -0.48112196448134054 y절편 45.508362246247714
# 학습 횟수 1690 기울기 -0.4849762782452321 y절편 45.566387091700605
# 학습 횟수 1700 기울기 -0.4887726840299374 y절편 45.6235401602955
# 학습 횟수 1710 기울기 -0.49251205185649266 y절편 45.679834549781916
# 학습 횟수 1720 기울기 -0.49619523867456444 y절편 45.73528316112614
# 학습 횟수 1730 기울기 -0.4998230885588356 y절편 45.78989870146776
# 학습 횟수 1740 기울기 -0.5033964329024425 y절편 45.843693687031774
# 학습 횟수 1750 기울기 -0.5069160906075059 y절편 45.89668044599692
# 학습 횟수 1760 기울기 -0.5103828682727987 y절편 45.94887112132093
# 학습 횟수 1770 기울기 -0.5137975603785908 y절편 46.000277673523286
# 학습 횟수 1780 기울기 -0.5171609494687214 y절편 46.050911883426245
# 학습 횟수 1790 기울기 -0.5204738063299377 y절편 46.100785354854665
# 학습 횟수 1800 기울기 -0.5237368901685318 y절편 46.14990951729521
# 학습 횟수 1810 기울기 -0.5269509487843279 y절편 46.19829562851563
# 학습 횟수 1820 기울기 -0.5301167187420582 y절편 46.24595477714478
# 학습 횟수 1830 기울기 -0.5332349255401567 y절편 46.29289788521368
# 학습 횟수 1840 기울기 -0.5363062837770272 y절편 46.33913571065862
# 학습 횟수 1850 기울기 -0.5393314973148023 y절편 46.38467884978649
# 학습 횟수 1860 기울기 -0.5423112594406507 y절편 46.42953773970316
# 학습 횟수 1870 기울기 -0.5452462530256552 y절편 46.47372266070531
# 학습 횟수 1880 기울기 -0.5481371506813075 y절편 46.51724373863644
# 학습 횟수 1890 기울기 -0.5509846149136517 y절편 46.56011094720733
# 학습 횟수 1900 기울기 -0.553789298275106 y절편 46.60233411028172
# 학습 횟수 1910 기울기 -0.5565518435140132 y절편 46.64392290412769
# 학습 횟수 1920 기울기 -0.559272883721936 y절편 46.68488685963514
# 학습 횟수 1930 기울기 -0.5619530424787424 y절편 46.72523536449995
# 학습 횟수 1940 기울기 -0.5645929339955132 y절편 46.76497766537541
# 학습 횟수 1950 기울기 -0.5671931632552986 y절편 46.80412286999124
# 학습 횟수 1960 기울기 -0.5697543261517631 y절편 46.84267994924079
# 학습 횟수 1970 기울기 -0.5722770096257451 y절편 46.880657739236945
# 학습 횟수 1980 기울기 -0.5747617917997676 y절편 46.91806494333704
# 학습 횟수 1990 기울기 -0.577209242110524 y절편 46.954910134137464
# 학습 횟수 2000 기울기 -0.5796199214393797 y절편 46.99120175543818
# 학습 횟수 2010 기울기 -0.5819943822409042 y절편 47.026948124177835
# 학습 횟수 2020 기울기 -0.5843331686694809 y절편 47.062157432339724
# 학습 횟수 2030 기울기 -0.586636816704008 y절편 47.096837748829145
# 학습 횟수 2040 기울기 -0.5889058542707298 y절편 47.130997021322536
# 학습 횟수 2050 기울기 -0.591140801364222 y절편 47.1646430780889
# 학습 횟수 2060 기울기 -0.5933421701665587 y절편 47.19778362978374
# 학습 횟수 2070 기울기 -0.5955104651646859 y절편 47.23042627121612
# 학습 횟수 2080 기울기 -0.5976461832660391 y절편 47.26257848308919
# 학습 횟수 2090 기울기 -0.5997498139124172 y절편 47.29424763371454
# 학습 횟수 2100 기울기 -0.6018218391921477 y절편 47.32544098070076
# 학습 횟수 2110 기울기 -0.6038627339505659 y절편 47.35616567261667
# 학습 횟수 2120 기울기 -0.6058729658988353 y절편 47.386428750629555
# 학습 횟수 2130 기울기 -0.6078529957211372 y절편 47.416237150118846
# 학습 횟수 2140 기울기 -0.6098032771802385 y절편 47.44559770226542
# 학습 횟수 2150 기울기 -0.6117242572214838 y절편 47.4745171356171
# 학습 횟수 2160 기울기 -0.6136163760752238 y절편 47.50300207763072
# 학습 횟수 2170 기울기 -0.6154800673576988 y절편 47.53105905619084
# 학습 횟수 2180 기울기 -0.6173157581704125 y절편 47.558694501105805
# 학습 횟수 2190 기울기 -0.6191238691980115 y절편 47.58591474558122
# 학습 횟수 2200 기울기 -0.6209048148046916 y절편 47.61272602767136
# 학습 횟수 2210 기울기 -0.6226590031291567 y절편 47.639134491708695
# 학습 횟수 2220 기울기 -0.6243868361781557 y절편 47.66514618971206
# 학습 횟수 2230 기울기 -0.6260887099186059 y절편 47.690767082773505
# 학습 횟수 2240 기울기 -0.6277650143683409 y절편 47.716003042424504
# 학습 횟수 2250 기울기 -0.6294161336854858 y절편 47.74085985198141
# 학습 횟수 2260 기울기 -0.6310424462565006 y절편 47.76534320787093
# 학습 횟수 2270 기울기 -0.6326443247828877 y절편 47.78945872093545
# 학습 횟수 2280 기울기 -0.6342221363666112 y절편 47.813211917719016
# 학습 횟수 2290 기울기 -0.6357762425942206 y절편 47.836608241733735
# 학습 횟수 2300 기울기 -0.6373069996197167 y절편 47.8596530547073
# 학습 횟수 2310 기울기 -0.6388147582461713 y절편 47.882351637811745
# 학습 횟수 2320 기울기 -0.6402998640061218 y절편 47.90470919287371
# 학습 횟수 2330 기울기 -0.6417626572407558 y절편 47.92673084356659
# 학습 횟수 2340 기울기 -0.6432034731779063 y절편 47.94842163658464
# 학습 횟수 2350 기울기 -0.6446226420088763 y절편 47.9697865427996
# 학습 횟수 2360 기울기 -0.6460204889641094 y절편 47.99083045839985
# 학습 횟수 2370 기울기 -0.647397334387722 y절편 48.011558206012424
# 학습 횟수 2380 기울기 -0.6487534938109156 y절편 48.031974535808274
# 학습 횟수 2390 기울기 -0.6500892780242894 y절편 48.05208412659083
# 학습 횟수 2400 기울기 -0.6514049931490621 y절편 48.07189158686823
# 학습 횟수 2410 기울기 -0.6527009407072253 y절편 48.0914014559095
# 학습 횟수 2420 기울기 -0.6539774176906455 y절편 48.11061820478474
# 학습 횟수 2430 기울기 -0.6552347166291219 y절편 48.12954623738983
# 학습 횟수 2440 기울기 -0.6564731256574314 y절편 48.14818989145565
# 학습 횟수 2450 기울기 -0.6576929285813523 y절편 48.1665534395421
# 학습 횟수 2460 기울기 -0.6588944049427107 y절편 48.18464109001732
# 학습 횟수 2470 기울기 -0.66007783008344 y절편 48.20245698802209
# 학습 횟수 2480 기울기 -0.6612434752086812 y절편 48.22000521641976
# 학습 횟수 2490 기울기 -0.6623916074489357 y절편 48.237289796731915
# 학습 횟수 2500 기울기 -0.6635224899212829 y절편 48.25431469006003
# 학습 횟수 2510 기울기 -0.6646363817896773 y절편 48.27108379799315
# 학습 횟수 2520 기울기 -0.6657335383243438 y절편 48.2876009635021
# 학습 횟수 2530 기울기 -0.6668142109602754 y절편 48.30386997182014
# 학습 횟수 2540 기울기 -0.6678786473548582 y절편 48.319894551310455
# 학습 횟수 2550 기울기 -0.6689270914446207 y절편 48.33567837432051
# 학습 횟수 2560 기울기 -0.6699597835011438 y절편 48.35122505802372
# 학습 횟수 2570 기울기 -0.6709769601861173 y절편 48.36653816524836
# 학습 횟수 2580 기울기 -0.6719788546055788 y절편 48.38162120529403
# 학습 횟수 2590 기울기 -0.6729656963633379 y절편 48.39647763473599
# 학습 횟수 2600 기울기 -0.6739377116135857 y절편 48.411110858217135
# 학습 횟수 2610 기울기 -0.674895123112731 y절편 48.42552422922838
# 학습 횟수 2620 기울기 -0.6758381502704446 y절편 48.439721050877104
# 학습 횟수 2630 기울기 -0.6767670091999425 y절편 48.45370457664415
# 학습 횟수 2640 기울기 -0.6776819127675139 y절편 48.467478011129415
# 학습 횟수 2650 기울기 -0.6785830706413 y절편 48.48104451078623
# 학습 횟수 2660 기울기 -0.6794706893393478 y절편 48.49440718464476
# 학습 횟수 2670 기울기 -0.6803449722769364 y절편 48.50756909502448
# 학습 횟수 2680 기울기 -0.6812061198131922 y절편 48.520533258235965
# 학습 횟수 2690 기울기 -0.6820543292970059 y절편 48.53330264527214
# 학습 횟수 2700 기울기 -0.6828897951122593 y절편 48.54588018248911
# 학습 횟수 2710 기울기 -0.683712708722372 y절편 48.55826875227686
# 학습 횟수 2720 기울기 -0.6845232587141786 y절편 48.570471193719754
# 학습 횟수 2730 기울기 -0.6853216308411487 y절편 48.58249030324719
# 학습 횟수 2740 기울기 -0.6861080080659544 y절편 48.594328835274474
# 학습 횟수 2750 기울기 -0.6868825706023989 y절편 48.605989502833985
# 학습 횟수 2760 기울기 -0.6876454959567188 y절편 48.617474978196995
# 학습 횟수 2770 기울기 -0.6883969589682594 y절편 48.62878789348601
# 학습 횟수 2780 기울기 -0.6891371318495462 y절편 48.63993084127803
# 학습 횟수 2790 기울기 -0.6898661842257501 y절편 48.650906375198645
# 학습 횟수 2800 기울기 -0.6905842831735587 y절편 48.661717010507274
# 학습 횟수 2810 기울기 -0.6912915932594655 y절편 48.67236522467357
# 학습 횟수 2820 기울기 -0.6919882765774861 y절편 48.6828534579452
# 학습 횟수 2830 기울기 -0.6926744927863007 y절편 48.69318411390703
# 학습 횟수 2840 기울기 -0.6933503991458466 y절편 48.70335956003202
# 학습 횟수 2850 기울기 -0.6940161505533575 y절편 48.713382128223735
# 학습 횟수 2860 기울기 -0.6946718995788597 y절편 48.723254115350755
# 학습 횟수 2870 기울기 -0.695317796500137 y절편 48.73297778377306
# 학습 횟수 2880 기울기 -0.6959539893371691 y절편 48.74255536186046
# 학습 횟수 2890 기울기 -0.6965806238860531 y절편 48.75198904450329
# 학습 횟수 2900 기울기 -0.6971978437524196 y절편 48.76128099361544
# 학습 횟수 2910 기울기 -0.6978057903843355 y절편 48.77043333862975
# 학습 횟수 2920 기울기 -0.6984046031047273 y절편 48.77944817698606
# 학습 횟수 2930 기울기 -0.6989944191433035 y절편 48.78832757461181
# 학습 횟수 2940 기울기 -0.6995753736680086 y절편 48.7970735663956
# 학습 횟수 2950 기울기 -0.7001475998159948 y절편 48.805688156653424
# 학습 횟수 2960 기울기 -0.7007112287241347 y절편 48.814173319588
# 학습 횟수 2970 기울기 -0.7012663895590769 y절편 48.82253099974129
# 학습 횟수 2980 기울기 -0.7018132095468431 y절편 48.83076311244003
# 학습 횟수 2990 기울기 -0.702351814001985 y절편 48.83887154423472
# 학습 횟수 3000 기울기 -0.702882326356305 y절편 48.84685815333195
# 학습 횟수 3010 기울기 -0.7034048681871405 y절편 48.854724770020226
# 학습 횟수 3020 기울기 -0.7039195592452269 y절편 48.86247319708946
# 학습 횟수 3030 기울기 -0.7044265174821402 y절편 48.870105210244056
# 학습 횟수 3040 기울기 -0.7049258590773296 y절편 48.87762255850991
# 학습 횟수 3050 기울기 -0.7054176984647401 y절편 48.885026964635195
# 학습 횟수 3060 기울기 -0.705902148359039 y절편 48.89232012548518
# 학습 횟수 3070 기울기 -0.7063793197814453 y절편 48.89950371243107
# 학습 횟수 3080 기울기 -0.7068493220851735 y절편 48.90657937173307
# 학습 횟수 3090 기울기 -0.707312262980493 y절편 48.91354872491765
# 학습 횟수 3100 기울기 -0.7077682485594137 y절편 48.92041336914913
# 학습 횟수 3110 기울기 -0.7082173833199961 y절편 48.92717487759571
# 학습 횟수 3120 기울기 -0.7086597701903027 y절편 48.933834799790006
# 학습 횟수 3130 기울기 -0.709095510551984 y절편 48.94039466198416
# 학습 횟수 3140 기울기 -0.7095247042635111 y절편 48.94685596749955
# 학습 횟수 3150 기울기 -0.7099474496830633 y절편 48.95322019707143
# 학습 횟수 3160 기울기 -0.7103638436910653 y절편 48.95948880918811
# 학습 횟수 3170 기울기 -0.7107739817123926 y절편 48.96566324042534
# 학습 횟수 3180 기울기 -0.7111779577382363 y절편 48.97174490577544
# 학습 횟수 3190 기울기 -0.7115758643476481 y절편 48.97773519897162
# 학습 횟수 3200 기울기 -0.7119677927287502 y절편 48.983635492807345
# 학습 횟수 3210 기울기 -0.7123538326996381 y절편 48.989447139450974
# 학습 횟수 3220 기울기 -0.7127340727289622 y절편 48.99517147075561
# 학습 횟수 3230 기울기 -0.7131085999562021 y절편 49.00080979856433
# 학습 횟수 3240 기울기 -0.7134775002116365 y절편 49.00636341501083
# 학습 횟수 3250 기울기 -0.7138408580360127 y절편 49.01183359281551
# 학습 횟수 3260 기울기 -0.7141987566999204 y절편 49.017221585577175
# 학습 횟수 3270 기울기 -0.714551278222877 y절편 49.02252862806033
# 학습 횟수 3280 기울기 -0.7148985033921208 y절편 49.0277559364781
# 학습 횟수 3290 기울기 -0.7152405117811265 y절편 49.032904708771
# 학습 횟수 3300 기울기 -0.7155773817678422 y절편 49.03797612488144
# 학습 횟수 3310 기울기 -0.7159091905526483 y절편 49.042971347024135
# 학습 횟수 3320 기울기 -0.7162360141760539 y절편 49.04789151995248
# 학습 횟수 3330 기울기 -0.7165579275361171 y절편 49.05273777122083
# 학습 횟수 3340 기울기 -0.7168750044056161 y절편 49.05751121144299
# 학습 횟수 3350 기울기 -0.7171873174489491 y절편 49.062212934546615
# 학습 횟수 3360 기울기 -0.7174949382387923 y절편 49.066844018024035
# 학습 횟수 3370 기울기 -0.7177979372724965 y절편 49.07140552317905
# 학습 횟수 3380 기울기 -0.7180963839882499 y절편 49.0758984953703
# 학습 횟수 3390 기울기 -0.7183903467809856 y절편 49.0803239642507
# 학습 횟수 3400 기울기 -0.7186798930180573 y절편 49.084682944003454
# 학습 횟수 3410 기울기 -0.7189650890546798 y절편 49.088976433574494
# 학습 횟수 3420 기울기 -0.7192460002491321 y절편 49.09320541690138
# 학습 횟수 3430 기울기 -0.7195226909777376 y절편 49.097370863138785
# 학습 횟수 3440 기울기 -0.7197952246496185 y절편 49.101473726880634
# 학습 횟수 3450 기울기 -0.7200636637212237 y절편 49.105514948378826
# 학습 횟수 3460 기울기 -0.7203280697106448 y절편 49.109495453758726
# 학습 횟수 3470 기울기 -0.7205885032117142 y절편 49.11341615523141
# 학습 횟수 3480 기울기 -0.720845023907889 y절편 49.117277951302725
# 학습 횟수 3490 기울기 -0.7210976905859308 y절편 49.12108172697917
# 학습 횟수 3500 기울기 -0.7213465611493779 y절편 49.12482835397074
# 학습 횟수 3510 기울기 -0.7215916926318136 y절편 49.128518690890694
# 학습 횟수 3520 기울기 -0.7218331412099367 y절편 49.132153583452286
# 학습 횟수 3530 기울기 -0.7220709622164367 y절편 49.135733864662626
# 학습 횟수 3540 기울기 -0.7223052101526737 y절편 49.139260355013555
# 학습 횟수 3550 기울기 -0.7225359387011682 y절편 49.14273386266967
# 학습 횟수 3560 기울기 -0.7227632007379045 y절편 49.14615518365357
# 학습 횟수 3570 기울기 -0.7229870483444466 y절편 49.14952510202822
# 학습 횟수 3580 기울기 -0.7232075328198754 y절편 49.15284439007669
# 학습 횟수 3590 기울기 -0.7234247046925427 y절편 49.15611380847907
# 학습 횟수 3600 기울기 -0.7236386137316546 y절편 49.15933410648691
# 학습 횟수 3610 기울기 -0.7238493089586745 y절편 49.162506022094824
# 학습 횟수 3620 기울기 -0.7240568386585556 y절편 49.165630282209634
# 학습 횟수 3630 기울기 -0.7242612503908092 y절편 49.16870760281697
# 학습 횟수 3640 기울기 -0.724462591000404 y절편 49.17173868914538
# 학습 횟수 3650 기울기 -0.7246609066284982 y절편 49.17472423582787
# 학습 횟수 3660 기울기 -0.7248562427230189 y절편 49.17766492706119
# 학습 횟수 3670 기울기 -0.7250486440490725 y절편 49.180561436762545
# 학습 횟수 3680 기울기 -0.7252381546992058 y절편 49.18341442872409
# 학습 횟수 3690 기울기 -0.7254248181035122 y절편 49.186224556765055
# 학습 횟수 3700 기울기 -0.7256086770395792 y절편 49.1889924648815
# 학습 횟수 3710 기울기 -0.7257897736422989 y절편 49.19171878739404
# 학습 횟수 3720 기울기 -0.7259681494135184 y절편 49.19440414909305
# 학습 횟수 3730 기울기 -0.7261438452315528 y절편 49.19704916538199
# 학습 횟수 3740 기울기 -0.7263169013605547 y절편 49.19965444241835
# 학습 횟수 3750 기울기 -0.7264873574597368 y절편 49.202220577252575
# 학습 횟수 3760 기울기 -0.7266552525924672 y절편 49.20474815796493
# 학습 횟수 3770 기울기 -0.7268206252352175 y절편 49.207237763800244
# 학습 횟수 3780 기울기 -0.7269835132863798 y절편 49.20968996530064
# 학습 횟수 3790 기울기 -0.7271439540749545 y절편 49.212105324436315
# 학습 횟수 3800 기울기 -0.7273019843691023 y절편 49.214484394734306
# 학습 횟수 3810 기울기 -0.7274576403845732 y절편 49.21682772140535
# 학습 횟수 3820 기울기 -0.7276109577930036 y절편 49.21913584146884
# 학습 횟수 3830 기울기 -0.7277619717300929 y절편 49.22140928387587
# 학습 횟수 3840 기울기 -0.7279107168036533 y절편 49.22364856963046
# 학습 횟수 3850 기울기 -0.728057227101544 y절편 49.225854211908995
# 학습 횟수 3860 기울기 -0.7282015361994805 y절편 49.22802671617776
# 학습 횟수 3870 기울기 -0.728343677168731 y절편 49.23016658030885
# 학습 횟수 3880 기울기 -0.728483682583692 y절편 49.232274294694164
# 학습 횟수 3890 기울기 -0.7286215845293589 y절편 49.23435034235793
# 학습 횟수 3900 기울기 -0.7287574146086723 y절편 49.236395199067275
# 학습 횟수 3910 기울기 -0.7288912039497676 y절편 49.238409333441346
# 학습 횟수 3920 기울기 -0.7290229832131021 y절편 49.24039320705862
# 학습 횟수 3930 기울기 -0.7291527825984846 y절편 49.24234727456274
# 학습 횟수 3940 기울기 -0.7292806318519981 y절편 49.244271983766716
# 학습 횟수 3950 기울기 -0.7294065602728114 y절편 49.246167775755495
# 학습 횟수 3960 기울기 -0.7295305967199 y절편 49.24803508498711
# 학습 횟수 3970 기울기 -0.7296527696186534 y절편 49.24987433939216
# 학습 횟수 3980 기울기 -0.7297731069673945 y절편 49.25168596047198
# 학습 횟수 3990 기울기 -0.7298916363437925 y절편 49.25347036339516
# 학습 횟수 4000 기울기 -0.7300083849111846 y절편 49.2552279570927
# 학습 횟수 4010 기울기 -0.730123379424801 y절편 49.256959144351775
# 학습 횟수 4020 기울기 -0.730236646237896 y절편 49.25866432190798
# 학습 횟수 4030 기울기 -0.7303482113077855 y절편 49.260343880536276
# 학습 횟수 4040 기울기 -0.7304581002018016 y절편 49.261998205140564
# 학습 횟수 4050 기울기 -0.7305663381031425 y절편 49.263627674841835
# 학습 횟수 4060 기울기 -0.7306729498166533 y절편 49.265232663065134
# 학습 횟수 4070 기울기 -0.7307779597745041 y절편 49.266813537625055
# 학습 횟수 4080 기울기 -0.7308813920417914 y절편 49.2683706608101
# 학습 횟수 4090 기울기 -0.7309832703220536 y절편 49.269904389465665
# 학습 횟수 4100 기울기 -0.7310836179627018 y절편 49.27141507507583
# 학습 횟수 4110 기울기 -0.7311824579603698 y절편 49.27290306384389
# 학습 횟수 4120 기울기 -0.7312798129661879 y절편 49.27436869677175
# 학습 횟수 4130 기울기 -0.731375705290971 y절편 49.27581230973803
# 학습 횟수 4140 기울기 -0.7314701569103284 y절편 49.27723423357499
# 학습 횟수 4150 기울기 -0.7315631894697073 y절편 49.278634794144445
# 학습 횟수 4160 기울기 -0.7316548242893472 y절편 49.2800143124124
# 학습 횟수 4170 기울기 -0.7317450823691696 y절편 49.28137310452259
# 학습 횟수 4180 기울기 -0.7318339843935887 y절편 49.28271148186895
# 학습 횟수 4190 기울기 -0.7319215507362508 y절편 49.28402975116696
# 학습 횟수 4200 기울기 -0.7320078014647052 y절편 49.28532821452396
# 학습 횟수 4210 기울기 -0.7320927563450017 y절편 49.28660716950833
# 학습 횟수 4220 기울기 -0.7321764348462232 y절편 49.28786690921779
# 학습 횟수 4230 기울기 -0.7322588561449432 y절편 49.289107722346465
# 학습 횟수 4240 기울기 -0.7323400391296223 y절편 49.29032989325106
# 학습 횟수 4250 기울기 -0.7324200024049373 y절편 49.29153370201607
# 학습 횟수 4260 기울기 -0.7324987642960467 y절편 49.292719424517955
# 학습 횟수 4270 기울기 -0.7325763428527851 y절편 49.29388733248834
# 학습 횟수 4280 기울기 -0.7326527558538051 y절편 49.295037693576305
# 학습 횟수 4290 기울기 -0.7327280208106487 y절편 49.29617077140971
# 학습 횟수 4300 기울기 -0.7328021549717597 y절편 49.29728682565562
# 학습 횟수 4310 기울기 -0.7328751753264396 y절편 49.29838611207981
# 학습 횟수 4320 기울기 -0.7329470986087376 y절편 49.29946888260537
# 학습 횟수 4330 기울기 -0.7330179413012893 y절편 49.30053538537047
# 학습 횟수 4340 기울기 -0.733087719639091 y절편 49.30158586478521
# 학습 횟수 4350 기울기 -0.7331564496132196 y절편 49.302620561587574
# 학습 횟수 4360 기울기 -0.7332241469745 y절편 49.30363971289867
# 학습 횟수 4370 기울기 -0.7332908272371141 y절편 49.304643552277085
# 학습 횟수 4380 기울기 -0.7333565056821567 y절편 49.305632309772356
# 학습 횟수 4390 기울기 -0.7334211973611322 y절편 49.30660621197767
# 학습 횟수 4400 기울기 -0.7334849170994127 y절편 49.3075654820819
# 학습 횟수 4410 기울기 -0.7335476794996281 y절편 49.30851033992064
# 학습 횟수 4420 기울기 -0.7336094989450188 y절편 49.30944100202666
# 학습 횟수 4430 기울기 -0.7336703896027243 y절편 49.31035768167947
# 학습 횟수 4440 기울기 -0.7337303654270366 y절편 49.31126058895423
# 학습 횟수 4450 기울기 -0.7337894401625951 y절편 49.3121499307699
# 학습 횟수 4460 기울기 -0.7338476273475374 y절편 49.31302591093665
# 학습 횟수 4470 기울기 -0.733904940316601 y절편 49.313888730202564
# 학습 횟수 4480 기울기 -0.7339613922041793 y절편 49.31473858629963
# 학습 횟수 4490 기울기 -0.7340169959473324 y절편 49.31557567398909
# 학습 횟수 4500 기울기 -0.7340717642887506 y절편 49.31640018510603
# 학습 횟수 4510 기울기 -0.7341257097796788 y절편 49.31721230860343
# 학습 횟수 4520 기울기 -0.7341788447827857 y절편 49.31801223059533
# 학습 횟수 4530 기울기 -0.7342311814750017 y절편 49.31880013439958
# 학습 횟수 4540 기울기 -0.7342827318503092 y절편 49.31957620057984
# 학습 횟수 4550 기울기 -0.7343335077224898 y절편 49.32034060698692
# 학습 횟수 4560 기울기 -0.7343835207278345 y절편 49.3210935287996
# 학습 횟수 4570 기울기 -0.7344327823278052 y절편 49.321835138564694
# 학습 횟수 4580 기울기 -0.7344813038116663 y절편 49.32256560623667
# 학습 횟수 4590 기울기 -0.73452909629907 y절편 49.32328509921657
# 학습 횟수 4600 기울기 -0.7345761707426067 y절편 49.32399378239036
# 학습 횟수 4610 기울기 -0.7346225379303088 y절편 49.32469181816672
# 학습 횟수 4620 기울기 -0.7346682084881287 y절편 49.325379366514255
# 학습 횟수 4630 기울기 -0.734713192882374 y절편 49.32605658499821
# 학습 횟수 4640 기울기 -0.7347575014221034 y절편 49.326723628816524
# 학습 횟수 4650 기울기 -0.734801144261489 y절편 49.32738065083538
# 학습 횟수 4660 기울기 -0.7348441314021449 y절편 49.328027801624295
# 학습 횟수 4670 기울기 -0.734886472695422 y절편 49.328665229490625
# 학습 횟수 4680 기울기 -0.7349281778446585 y절편 49.32929308051347
# 학습 횟수 4690 기울기 -0.7349692564074103 y절편 49.32991149857726
# 학습 횟수 4700 기울기 -0.7350097177976375 y절편 49.330520625404645
# 학습 횟수 4710 기울기 -0.7350495712878627 y절편 49.331120600589
# 학습 횟수 4720 기울기 -0.7350888260112965 y절편 49.33171156162645
# 학습 횟수 4730 기울기 -0.7351274909639323 y절편 49.332293643947345
# 학습 횟수 4740 기울기 -0.735165575006603 y절편 49.33286698094727
# 학습 횟수 4750 기울기 -0.735203086867016 y절편 49.3334317040177
# 학습 횟수 4760 기울기 -0.7352400351417526 y절편 49.333987942576016
# 학습 횟수 4770 기울기 -0.7352764282982358 y절편 49.33453582409523
# 학습 횟수 4780 기울기 -0.7353122746766724 y절편 49.33507547413315
# 학습 횟수 4790 기울기 -0.7353475824919671 y절편 49.335607016361216
# 학습 횟수 4800 기울기 -0.735382359835597 y절편 49.33613057259276
# 학습 횟수 4810 기울기 -0.7354166146774764 y절편 49.336646262811
# 학습 횟수 4820 기울기 -0.7354503548677761 y절편 49.3371542051965
# 학습 횟수 4830 기울기 -0.7354835881387224 y절편 49.33765451615421
# 학습 횟수 4840 기울기 -0.7355163221063733 y절편 49.33814731034025
# 학습 횟수 4850 기울기 -0.7355485642723616 y절편 49.33863270068809
# 학습 횟수 4860 기울기 -0.735580322025614 y절편 49.339110798434476
# 학습 횟수 4870 기울기 -0.7356116026440439 y절편 49.339581713144916
# 학습 횟수 4880 기울기 -0.7356424132962189 y절편 49.34004555273875
# 학습 횟수 4890 기울기 -0.7356727610430075 y절편 49.340502423513975
# 학습 횟수 4900 기울기 -0.7357026528391916 y절편 49.340952430171484
# 학습 횟수 4910 기울기 -0.7357320955350651 y절편 49.34139567583918
# 학습 횟수 4920 기울기 -0.7357610958779996 y절편 49.341832262095494
# 학습 횟수 4930 기울기 -0.7357896605139939 y절편 49.342262288992764
# 학습 횟수 4940 기울기 -0.7358177959891964 y절편 49.34268585508011
# 학습 횟수 4950 기울기 -0.7358455087514051 y절편 49.343103057426035
# 학습 횟수 4960 기울기 -0.7358728051515435 y절편 49.343513991640656
# 학습 횟수 4970 기울기 -0.735899691445119 y절편 49.343918751897625
# 학습 횟수 4980 기울기 -0.7359261737936538 y절편 49.34431743095571
# 학습 횟수 4990 기울기 -0.7359522582660998 y절편 49.344710120180075
# 학습 횟수 5000 기울기 -0.7359779508402255 y절편 49.34509690956315
# 학습 횟수 5010 기울기 -0.736003257403991 y절편 49.34547788774537
# 학습 횟수 5020 기울기 -0.7360281837568916 y절편 49.34585314203533
# 학습 횟수 5030 기울기 -0.7360527356112921 y절편 49.34622275842995
# 학습 횟수 5040 기울기 -0.7360769185937316 y절편 49.34658682163409
# 학습 횟수 5050 기울기 -0.7361007382462168 y절편 49.34694541508
# 학습 횟수 5060 기울기 -0.7361242000274885 y절편 49.3472986209464
# 학습 횟수 5070 기울기 -0.7361473093142774 y절편 49.34764652017739
# 학습 횟수 5080 기울기 -0.7361700714025299 y절편 49.347989192500904
# 학습 횟수 5090 기울기 -0.7361924915086253 y절편 49.34832671644704
# 학습 횟수 5100 기울기 -0.7362145747705725 y절편 49.348659169366044
# 학습 횟수 5110 기울기 -0.7362363262491856 y절편 49.34898662744606
# 학습 횟수 5120 기울기 -0.7362577509292428 y절편 49.349309165730524
# 학습 횟수 5130 기울기 -0.7362788537206304 y절편 49.34962685813543
# 학습 횟수 5140 기울기 -0.73629963945947 y절편 49.349939777466254
# 학습 횟수 5150 기울기 -0.7363201129092202 y절편 49.35024799543459
# 학습 횟수 5160 기울기 -0.7363402787617763 y절편 49.35055158267467
# 학습 횟수 5170 기울기 -0.7363601416385381 y절편 49.35085060875946
# 학습 횟수 5180 기울기 -0.7363797060914761 y절편 49.35114514221668
# 학습 횟수 5190 기울기 -0.7363989766041684 y절편 49.35143525054446
# 학습 횟수 5200 기울기 -0.736417957592833 y절편 49.35172100022683
# 학습 횟수 5210 기울기 -0.7364366534073353 y절편 49.35200245674894
# 학습 횟수 5220 기울기 -0.7364550683321891 y절편 49.35227968461209
# 학습 횟수 5230 기울기 -0.7364732065875372 y절편 49.352552747348504
# 학습 횟수 5240 기울기 -0.7364910723301172 y절편 49.352821707535874
# 학습 횟수 5250 기울기 -0.7365086696542162 y절편 49.353086626811724
# 학습 횟수 5260 기울기 -0.7365260025926057 y절편 49.353347565887496
# 학습 횟수 5270 기울기 -0.7365430751174692 y절편 49.35360458456251
# 학습 횟수 5280 기울기 -0.7365598911413119 y절편 49.35385774173766
# 학습 횟수 5290 기울기 -0.7365764545178566 y절편 49.354107095428894
# 학습 횟수 5300 기울기 -0.7365927690429273 y절편 49.35435270278051
# 학습 횟수 5310 기울기 -0.7366088384553161 y절편 49.354594620078245
# 학습 횟수 5320 기울기 -0.7366246664376469 y절편 49.35483290276223
# 학습 횟수 5330 기울기 -0.7366402566172127 y절편 49.35506760543962
# 학습 횟수 5340 기울기 -0.7366556125668099 y절편 49.355298781897154
# 학습 횟수 5350 기울기 -0.7366707378055555 y절편 49.35552648511345
# 학습 횟수 5360 기울기 -0.736685635799695 y절편 49.355750767271175
# 학습 횟수 5370 기울기 -0.736700309963398 y절편 49.355971679769006
# 학습 횟수 5380 기울기 -0.7367147636595373 y절편 49.35618927323339
# 학습 횟수 5390 기울기 -0.7367290002004612 y절편 49.35640359753014
# 학습 횟수 5400 기울기 -0.7367430228487525 y절편 49.35661470177587
# 학습 횟수 5410 기울기 -0.7367568348179769 y절편 49.35682263434928
# 학습 횟수 5420 기울기 -0.7367704392734196 y절편 49.35702744290221
# 학습 횟수 5430 기울기 -0.7367838393328086 y절편 49.357229174370566
# 학습 횟수 5440 기울기 -0.7367970380670312 y절편 49.35742787498509
# 학습 횟수 5450 기울기 -0.7368100385008374 y절편 49.35762359028193
# 학습 횟수 5460 기울기 -0.7368228436135309 y절편 49.35781636511309
# 학습 횟수 5470 기울기 -0.7368354563396564 y절편 49.35800624365672
# 학습 횟수 5480 기울기 -0.7368478795696674 y절편 49.35819326942721
# 학습 횟수 5490 기울기 -0.7368601161505919 y절편 49.35837748528521
# 학습 횟수 5500 기울기 -0.736872168886682 y절편 49.358558933447384
# 학습 횟수 5510 기울기 -0.736884040540059 y절편 49.35873765549615
# 학습 횟수 5520 기울기 -0.7368957338313472 y절편 49.3589136923892
# 학습 횟수 5530 기울기 -0.7369072514402933 y절편 49.35908708446883
# 학습 횟수 5540 기울기 -0.736918596006384 y절편 49.35925787147126
# 학습 횟수 5550 기울기 -0.7369297701294505 y절편 49.35942609253569
# 학습 횟수 5560 기울기 -0.736940776370261 y절편 49.35959178621326
# 학습 횟수 5570 기울기 -0.7369516172511139 y절편 49.35975499047596
# 학습 횟수 5580 기울기 -0.7369622952564093 y절편 49.35991574272525
# 학습 횟수 5590 기울기 -0.7369728128332214 y절편 49.360074079800654
# 학습 횟수 5600 기울기 -0.736983172391861 y절편 49.360230037988245
# 학습 횟수 5610 기울기 -0.7369933763064243 y절편 49.360383653028904
# 학습 횟수 5620 기울기 -0.7370034269153388 y절편 49.360534960126536
# 학습 횟수 5630 기울기 -0.7370133265218991 y절편 49.36068399395613
# 학습 횟수 5640 기울기 -0.7370230773947948 y절편 49.36083078867173
# 학습 횟수 5650 기울기 -0.7370326817686298 y절편 49.36097537791422
# 학습 횟수 5660 기울기 -0.7370421418444355 y절편 49.36111779481908
# 학습 횟수 5670 기울기 -0.7370514597901753 y절편 49.36125807202395
# 학습 횟수 5680 기울기 -0.7370606377412374 y절편 49.36139624167608
# 학습 횟수 5690 기울기 -0.7370696778009328 y절편 49.361532335439804
# 학습 횟수 5700 기울기 -0.7370785820409668 y절편 49.36166638450366
# 학습 횟수 5710 기울기 -0.7370873525019207 y절편 49.361798419587615
# 학습 횟수 5720 기울기 -0.7370959911937198 y절편 49.36192847095013
# 학습 횟수 5730 기울기 -0.737104500096089 y절편 49.36205656839501
# 학습 횟수 5740 기울기 -0.7371128811590107 y절편 49.362182741278325
# 학습 횟수 5750 기울기 -0.7371211363031704 y절편 49.362307018515054
# 학습 횟수 5760 기울기 -0.7371292674203977 y절편 49.36242942858579
# 학습 횟수 5770 기울기 -0.737137276374097 y절편 49.36254999954319
# 학습 횟수 5780 기울기 -0.7371451649996773 y절편 49.36266875901846
# 학습 횟수 5790 기울기 -0.7371529351049718 y절편 49.362785734227664
# 학습 횟수 5800 기울기 -0.7371605884706544 y절편 49.36290095197799
# 학습 횟수 5810 기울기 -0.7371681268506437 y절편 49.363014438673844
# 학습 횟수 5820 기울기 -0.7371755519725074 y절편 49.363126220322926
# 학습 횟수 5830 기울기 -0.7371828655378575 y절편 49.36323632254219
# 학습 횟수 5840 기울기 -0.7371900692227424 y절편 49.36334477056374
# 학습 횟수 5850 기울기 -0.7371971646780285 y절편 49.36345158924058
# 학습 횟수 5860 기울기 -0.7372041535297773 y절편 49.36355680305229
# 학습 횟수 5870 기울기 -0.7372110373796238 y절편 49.36366043611071
# 학습 횟수 5880 기울기 -0.737217817805136 y절편 49.36376251216537
# 학습 횟수 5890 기울기 -0.7372244963601834 y절편 49.36386305460904
# 학습 횟수 5900 기울기 -0.7372310745752868 y절편 49.36396208648297
# 학습 횟수 5910 기울기 -0.737237553957973 y절편 49.364059630482245
# 학습 횟수 5920 기울기 -0.7372439359931207 y절편 49.36415570896101
# 학습 횟수 5930 기울기 -0.7372502221432985 y절편 49.364250343937535
# 학습 횟수 5940 기울기 -0.7372564138491011 y절편 49.364343557099275
# 학습 횟수 5950 기울기 -0.7372625125294813 y절편 49.36443536980789
# 학습 횟수 5960 기울기 -0.7372685195820694 y절편 49.364525803104044
# 학습 횟수 5970 기울기 -0.7372744363835011 y절편 49.364614877712306
# 학습 횟수 5980 기울기 -0.7372802642897266 y절편 49.36470261404587
# 학습 횟수 5990 기울기 -0.7372860046363258 y절편 49.36478903221125
# 학습 횟수 6000 기울기 -0.737291658738813 y절편 49.364874152012874

# %%
from matplotlib.animation import FuncAnimation

fig = plt.figure()
ax = plt.axes()

X = np.array(x)
Y = List[0][0] * X + List[0][1]
line, = ax.plot(X, Y, color='red')

def update(frame):
    Y=List[frame][0] * X + List[frame][1]

    line.set_data(X, Y)
    return line,

plt.scatter(x, y)

ani = FuncAnimation(fig, update, len(List), interval=1 , blit=False)
ani.save('matplot.gif', writer='imagemagick')

plt.show()
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
W = np.linspace(0, max(x), 1000)
B = np.linspace(0, max(y), 1000)

WW, BB = np.meshgrid(W, B)
temp = np.zeros([len(W), len(B)])
for i in range(len(W)):
    for j in range(len(B)):
        yy = WW[i, j] * np.array(x) + BB[i, j]
        temp[i, j] = 1 / len(np.array(x)) * sum((np.array(y) - yy) ** 2)

# %%
fig = plt.figure(figsize=(9, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(WW,BB,temp,rstride=2,cstride=2,cmap=plt.cm.coolwarm,linewidth=0.5,antialiased=True)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')

plt.show()

# %%
# 그림 4-9 왼쪽
W = np.linspace(0, max(x), 1000)
B = np.linspace(0, max(y), 1000)

WW, BB = np.meshgrid(W, B)
temp = np.zeros([len(W), len(B)])
for i in range(len(W)):
    for j in range(len(B)):
        yy = WW[i, j] * np.array(x) + BB[i, j]
        temp[i, j] = 1 / len(np.array(x)) * sum((np.array(y) - yy) ** 2)

# %%
WW1 = np.array(List).T[0]
BB1 = np.array(List).T[1]
WWW, BBB = np.meshgrid(WW1, BB1)

temp = np.zeros([len(W), len(B)])
for i in range(len(W)):
    for j in range(len(B)):
        yy = WW[i, j] * np.array(x) + BB[i, j]
        temp[i, j] = 1 / len(np.array(x)) * sum((np.array(y) - yy) ** 2)

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

ax.plot_surface(WW, BB, temp,cmap=plt.cm.coolwarm, alpha=0.6)

data = np.array([np.array(List).T[0], np.array(List).T[1], ZZ])
ax.plot(WWW, BBB, temp, 'o-', c = 'k', alpha = 1, markersize = 7)

list_x = []
list_y = []


plt.show()
# Out:
# <ipython-input-64-742f13f3f9c4>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array([np.array(List).T[0], np.array(List).T[1], ZZ])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-742f13f3f9c4> in <cell line: 7>()
#       5
#       6 data = np.array([np.array(List).T[0], np.array(List).T[1], ZZ])
# ----> 7 ax.plot(WWW, BBB, temp, 'o-', c = 'k', alpha = 1, markersize = 7)
#       8
#       9 list_x = []
#
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1483
#    1484         # Match length
# -> 1485         zs = np.broadcast_to(zs, np.shape(xs))
#    1486
#    1487         lines = super().plot(xs, ys, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in broadcast_to(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in broadcast_to(array, shape, subok)
#     410            [1, 2, 3]])
#     411     """
# --> 412     return _broadcast_to(array, shape, subok=subok, readonly=True)
#     413
#     414
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in _broadcast_to(array, shape, subok, readonly)
#     346                          'negative')
#     347     extras = []
# --> 348     it = np.nditer(
#     349         (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     350         op_flags=['readonly'], itershape=shape, order='C')
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (1000,1000)  and requested shape (601,601)

# %%
data[2]
# Out:
# [782.8017764038083,
#  751.9809348339853,
#  724.0651342437095,
#  697.6021536898604,
#  672.5393465758298,
#  648.8257765526832,
#  626.4121642432062,
#  605.2508357545324,
#  585.2956727574018,
#  566.502064084845,
#  548.8268588045322,
#  532.2283207203747,
#  516.6660842603137,
#  502.10111170851303,
#  488.49565174143424,
#  475.8131992284702,
#  464.0184562590189,
#  453.0772943589941,
#  442.95671786090173,
#  433.62482839267085,
#  425.0507904514855,
#  417.204798029863,
#  410.05804226222057,
#  403.58268006111086,
#  397.7518037132469,
#  392.5394114063196,
#  387.9203786584899,
#  383.87043062328013,
#  380.3661152434067,
#  377.3847772278875,
#  374.9045328275378,
#  372.9042453847031,
#  371.36350163381275,
#  370.2625887300357,
#  369.5824719840068,
#  369.30477328124607,
#  369.41175016554627,
#  369.8862755662193,
#  370.71181814969555,
#  371.8724232765643,
#  373.35269454570346,
#  375.13777590770167,
#  377.21333433031464,
#  379.5655429992078,
#  382.1810650377511,
#  385.04703773011215,
#  388.1510572323732,
#  391.4811637568509,
#  395.02582721525346,
#  398.7739333067286,
#  402.7147700372919,
#  406.8380146575132,
#  411.1337210057525,
#  415.5923072446046,
#  420.20454397859135,
#  424.9615427414995,
#  429.85474484210806,
#  434.8759105573942,
#  440.0171086626288,
#  445.27070628809963,
#  450.62935909249825,
#  456.0860017433231,
#  461.6338386949249,
#  467.26633525511545,
#  472.97720893153075,
#  478.76042104920236,
#  484.6101686310569,
#  490.5208765332992,
#  496.4871898278975,
#  502.50396642460197,
#  508.5662699251756,
#  514.6693627027248,
#  520.8086991992379,
#  526.9799194346452,
#  533.1788427209218,
#  539.4014615749377,
#  545.6439358239675,
#  551.9025868979447,
#  558.1738923027183,
#  564.4544802687673,
#  570.7411245699627,
#  577.0307395071677,
#  583.3203750515859,
#  589.607212142957,
#  595.8885581378235,
#  602.1618424032432,
#  608.4246120514729,
#  614.6745278112633,
#  620.9093600315626,
#  627.1269848135312,
#  633.3253802669077,
#  639.5026228868778,
#  645.6568840477305,
#  651.7864266096748,
#  657.8896016353185,
#  663.9648452124131,
#  670.0106753795695,
#  676.0256891517447,
#  682.0085596424124,
#  687.958033279405,
#  693.8729271115224,
#  699.7521262030779,
#  705.5945811136544,
#  711.3993054604032,
#  717.1653735603231,
#  722.8919181500257,
#  728.578128180559,
#  734.2232466849539,
#  739.8265687162169,
#  745.3874393535655,
#  750.9052517747662,
#  756.3794453925137,
#  761.8095040528306,
#  767.1949542935488,
#  772.5353636609874,
#  777.8303390829867,
#  783.0795252965383,
#  788.2826033282839,
#  793.4392890262159,
#  798.5493316409712,
#  803.6125124551413,
#  808.6286434590943,
#  813.5975660718218,
#  818.5191499054014,
#  823.3932915716784,
#  828.2199135298272,
#  832.9989629735134,
#  837.7304107563602,
#  842.4142503545468,
#  847.0504968653062,
#  851.6391860402167,
#  856.180373352155,
#  860.6741330948372,
#  865.1205575139055,
#  869.5197559685598,
#  873.8718541227269,
#  878.1769931648513,
#  882.4353290553627,
#  886.6470318009372,
#  890.8122847546842,
#  894.931283941432,
#  899.0042374072842,
#  903.0313645926741,
#  907.0128957281436,
#  910.9490712521219,
#  914.8401412499735,
#  918.6863649136324,
#  922.4880100211474,
#  926.2453524354892,
#  929.9586756219826,
#  933.6282701837645,
#  937.254433414664,
#  940.8374688689365,
#  944.3776859472988,
#  947.8753994987221,
#  951.3309294374616,
#  954.7446003748285,
#  958.1167412651937,
#  961.4476850657752,
#  964.737768409726,
#  967.9873312920977,
#  971.196716768235,
#  974.3662706641954,
#  977.4963412987784,
#  980.5872792167852,
#  983.6394369331192,
#  986.6531686873672,
#  989.6288302085052,
#  992.5667784893822,
#  995.4673715706529,
#  998.3309683338267,
#  1001.1579283031402,
#  1003.9486114559287,
#  1006.7033780412145,
#  1009.422588406236,
#  1012.1066028306257,
#  1014.7557813679853,
#  1017.3704836945928,
#  1019.9510689650014,
#  1022.4978956742793,
#  1025.0113215266601,
#  1027.4917033103816,
#  1029.9393967784947,
#  1032.3547565354206,
#  1034.7381359290694,
#  1037.089886948302,
#  1039.4103601255558,
#  1041.699904444453,
#  1043.958867252199,
#  1046.1875941766011,
#  1048.386429047545,
#  1050.55571382277,
#  1052.6957885177644,
#  1054.8069911396533,
#  1056.889657624922,
#  1058.9441217808271,
#  1060.970715230366,
#  1062.9697673606672,
#  1064.9416052746767,
#  1066.8865537460076,
#  1068.8049351768443,
#  1070.6970695587715,
#  1072.5632744364295,
#  1074.403864873874,
#  1076.2191534235412,
#  1078.0094500977223,
#  1079.7750623424354,
#  1081.5162950136094,
#  1083.233450355489,
#  1084.9268279811665,
#  1086.596724855152,
#  1088.2434352779144,
#  1089.8672508722937,
#  1091.4684605717207,
#  1093.047350610164,
#  1094.6042045137299,
#  1096.139303093854,
#  1097.6529244420065,
#  1099.145343925856,
#  1100.6168341868167,
#  1102.067665138936,
#  1103.4981039690422,
#  1104.9084151381205,
#  1106.2988603838344,
#  1107.6696987241726,
#  1109.021186462134,
#  1110.353577191438,
#  1111.6671218031802,
#  1112.96206849342,
#  1114.2386627716216,
#  1115.497147469937,
#  1116.7377627532685,
#  1117.9607461300852,
#  1119.166332463949,
#  1120.354753985705,
#  1121.526240306323,
#  1122.6810184303367,
#  1123.8193127698514,
#  1124.9413451590954,
#  1126.0473348694804,
#  1127.1374986251399,
#  1128.212050618919,
#  1129.271202528788,
#  1130.3151635346578,
#  1131.3441403355644,
#  1132.3583371671991,
#  1133.3579558197732,
#  1134.343195656177,
#  1135.3142536304238,
#  1136.2713243063529,
#  1137.2145998765757,
#  1138.144270181639,
#  1139.060522729393,
#  1139.96354271455,
#  1140.853513038401,
#  1141.7306143286924,
#  1142.5950249596353,
#  1143.4469210720383,
#  1144.2864765935433,
#  1145.1138632589611,
#  1145.92925063068,
#  1146.7328061191436,
#  1147.5246950033861,
#  1148.3050804516122,
#  1149.074123541797,
#  1149.8319832823258,
#  1150.5788166326306,
#  1151.3147785238377,
#  1152.0400218793989,
#  1152.7546976357144,
#  1153.4589547627234,
#  1154.1529402844685,
#  1154.8367992996114,
#  1155.5106750019086,
#  1156.174708700624,
#  1156.829039840885,
#  1157.4738060239665,
#  1158.1091430275,
#  1158.7351848256092,
#  1159.3520636089522,
#  1159.9599098046754,
#  1160.5588520962724,
#  1161.1490174433427,
#  1161.7305311012415,
#  1162.3035166406307,
#  1162.8680959669018,
#  1163.4243893394964,
#  1163.9725153911015,
#  1164.5125911467146,
#  1165.044732042593,
#  1165.5690519450718,
#  1166.0856631692407,
#  1166.594676497501,
#  1167.096201197971,
#  1167.5903450427636,
#  1168.0772143261183,
#  1168.5569138823882,
#  1169.0295471038871,
#  1169.4952159585882,
#  1169.9540210076748,
#  1170.406061422941,
#  1170.8514350040462,
#  1171.2902381956142,
#  1171.7225661041823,
#  1172.1485125149998,
#  1172.5681699086645,
#  1172.9816294776183,
#  1173.3889811424701,
#  1173.7903135681838,
#  1174.1857141800936,
#  1174.5752691797707,
#  1174.9590635607367,
#  1175.3371811240133,
#  1175.7097044935238,
#  1176.0767151313287,
#  1176.4382933527188,
#  1176.794518341135,
#  1177.1454681629498,
#  1177.4912197820806,
#  1177.831849074457,
#  1178.167430842322,
#  1178.498038828396,
#  1178.8237457298674,
#  1179.1446232122476,
#  1179.460741923062,
#  1179.7721715053922,
#  1180.0789806112693,
#  1180.3812369149182,
#  1180.6790071258415,
#  1180.9723570017675,
#  1181.261351361442,
#  1181.546054097277,
#  1181.82652818785,
#  1182.1028357102575,
#  1182.3750378523303,
#  1182.6431949246903,
#  1182.9073663726874,
#  1183.1676107881694,
#  1183.4239859211316,
#  1183.6765486912166,
#  1183.9253551990723,
#  1184.1704607375882,
#  1184.4119198029748,
#  1184.6497861057196,
#  1184.884112581411,
#  1185.1149514014194,
#  1185.342353983455,
#  1185.5663710019892,
#  1185.7870523985482,
#  1186.0044473918797,
#  1186.218604487989,
#  1186.4295714900509,
#  1186.637395508193,
#  1186.8421229691626,
#  1187.0437996258636,
#  1187.2424705667718,
#  1187.4381802252385,
#  1187.6309723886607,
#  1187.8208902075482,
#  1188.0079762044593,
#  1188.1922722828385,
#  1188.3738197357188,
#  1188.5526592543279,
#  1188.7288309365692,
#  1188.9023742954082,
#  1189.0733282671288,
#  1189.241731219497,
#  1189.4076209598102,
#  1189.5710347428399,
#  1189.7320092786745,
#  1189.8905807404474,
#  1190.0467847719794,
#  1190.2006564952974,
#  1190.3522305180727,
#  1190.5015409409493,
#  1190.6486213647747,
#  1190.793504897737,
#  1190.9362241624028,
#  1191.0768113026622,
#  1191.215297990577,
#  1191.3517154331391,
#  1191.4860943789377,
#  1191.6184651247352,
#  1191.748857521949,
#  1191.8773009830522,
#  1192.003824487885,
#  1192.128456589873,
#  1192.2512254221713,
#  1192.372158703714,
#  1192.4912837451898,
#  1192.608627454928,
#  1192.7242163447077,
#  1192.8380765354805,
#  1192.9502337630277,
#  1193.060713383522,
#  1193.1695403790259,
#  1193.2767393629047,
#  1193.3823345851697,
#  1193.4863499377443,
#  1193.588808959661,
#  1193.6897348421742,
#  1193.7891504338209,
#  1193.8870782453905,
#  1193.9835404548382,
#  1194.078558912126,
#  1194.1721551439919,
#  1194.2643503586582,
#  1194.3551654504695,
#  1194.4446210044666,
#  1194.5327373008972,
#  1194.619534319657,
#  1194.7050317446794,
#  1194.78924896825,
#  1194.8722050952738,
#  1194.9539189474635,
#  1195.0344090674903,
#  1195.1136937230604,
#  1195.1917909109372,
#  1195.2687183609085,
#  1195.3444935396953,
#  1195.4191336548045,
#  1195.4926556583298,
#  1195.565076250697,
#  1195.6364118843512,
#  1195.7066787673953,
#  1195.7758928671813,
#  1195.8440699138403,
#  1195.9112254037677,
#  1195.9773746030596,
#  1196.0425325508945,
#  1196.10671406287,
#  1196.1699337342955,
#  1196.232205943427,
#  1196.293544854667,
#  1196.3539644217112,
#  1196.4134783906468,
#  1196.4721003030174,
#  1196.5298434988351,
#  1196.5867211195516,
#  1196.6427461109804,
#  1196.697931226191,
#  1196.7522890283487,
#  1196.8058318935143,
#  1196.8585720134095,
#  1196.9105213981347,
#  1196.9616918788588,
#  1197.0120951104573,
#  1197.0617425741136,
#  1197.1106455798956,
#  1197.1588152692793,
#  1197.2062626176426,
#  1197.2529984367256,
#  1197.2990333770463,
#  1197.3443779302902,
#  1197.3890424316612,
#  1197.4330370621972,
#  1197.4763718510537,
#  1197.519056677753,
#  1197.5611012744027,
#  1197.6025152278776,
#  1197.643307981975,
#  1197.6834888395344,
#  1197.7230669645269,
#  1197.7620513841166,
#  1197.8004509906887,
#  1197.838274543848,
#  1197.8755306723926,
#  1197.9122278762536,
#  1197.948374528407,
#  1197.9839788767595,
#  1198.0190490460081,
#  1198.0535930394656,
#  1198.0876187408683,
#  1198.1211339161505,
#  1198.1541462151954,
#  1198.18666317356,
#  1198.218692214175,
#  1198.2502406490187,
#  1198.2813156807676,
#  1198.311924404423,
#  1198.342073808908,
#  1198.3717707786523,
#  1198.401022095144,
#  1198.429834438458,
#  1198.458214388773,
#  1198.4861684278524,
#  1198.5137029405105,
#  1198.5408242160609,
#  1198.5675384497292,
#  1198.5938517440663,
#  1198.6197701103176,
#  1198.6452994697936,
#  1198.6704456551997,
#  1198.6952144119653,
#  1198.719611399538,
#  1198.7436421926727,
#  1198.7673122826852,
#  1198.7906270787016,
#  1198.813591908884,
#  1198.8362120216373,
#  1198.8584925867951,
#  1198.8804386968004,
#  1198.9020553678474,
#  1198.9233475410304,
#  1198.9443200834605,
#  1198.9649777893678,
#  1198.9853253811889,
#  1199.0053675106462,
#  1199.0251087597894,
#  1199.0445536420489,
#  1199.0637066032511,
#  1199.082572022637,
#  1199.101154213844,
#  1199.1194574258989,
#  1199.137485844175,
#  1199.1552435913409,
#  1199.1727347283068,
#  1199.189963255137,
#  1199.206933111965,
#  1199.2236481798866,
#  1199.2401122818442,
#  1199.2563291834915,
#  1199.272302594054,
#  1199.288036167174,
#  1199.3035335017328,
#  1199.3187981426806,
#  1199.3338335818341,
#  1199.3486432586717,
#  1199.3632305611254,
#  1199.3775988263383,
#  1199.391751341433,
#  1199.4056913442564,
#  1199.4194220241202,
#  1199.4329465225194,
#  1199.446267933857,
#  1199.45938930614,
#  1199.4723136416796,
#  1199.4850438977714,
#  1199.497582987372,
#  1199.509933779759,
#  1199.5220991011843,
#  1199.534081735524,
#  1199.5458844249076,
#  1199.5575098703418,
#  1199.568960732331,
#  1199.5802396314775,
#  1199.5913491490826,
#  1199.602291827737,
#  1199.6130701718932,
#  1199.6236866484462,
#  1199.6341436872838,
#  1199.6444436818538,
#  1199.6545889897002,
#  1199.664581933005,
#  1199.6744247991173,
#  1199.684119841074,
#  1199.6936692781112,
#  1199.7030752961796,
#  1199.7123400484313,
#  1199.7214656557198,
#  1199.7304542070806,
#  1199.7393077602069,
#  1199.7480283419206,
#  1199.756617948636,
#  1199.7650785468118,
#  1199.773412073403,
#  1199.7816204363014,
#  1199.7897055147746,
#  1199.7976691598867,
#  1199.8055131949316,
#  1199.8132394158408,
#  1199.8208495915978,
#  1199.8283454646407,
#  1199.8357287512586,
#  1199.843001141987,
#  1199.8501643019908,
#  1199.8572198714467,
#  1199.864169465916,
#  1199.8710146767132,
#  1199.8777570712716,
#  1199.8843981935024,
#  1199.8909395641424,
#  1199.8973826811048,
#  1199.9037290198214,
#  1199.90998003358,
#  1199.9161371538555,
#  1199.922201790635,
#  1199.9281753327455,
#  1199.9340591481653,
#  1199.9398545843403,
#  1199.9455629684903,
#  1199.9511856079114,
#  1199.9567237902786,
#  1199.9621787839367,
#  1199.9675518381912,
#  1199.9728441835953,
#  1199.9780570322262,
#  1199.9831915779685,
#  1199.9882489967829,
#  1199.9932304469783,
#  1199.9981370694734,
#  741.2968087459642,
#  718.0816324483756,
#  697.323644085715,
#  677.9109353171442,
#  659.7924752980817,
#  642.918919113281,
#  627.2425549091946,
#  612.717252765838,
#  599.2984151298743,
#  586.9429287618182,
#  575.6091181516605,
#  565.2567003585951,
#  555.8467412318472,
#  547.3416129709078,
#  539.7049529847135,
#  532.9016240105408,
#  526.8976754545495,
#  521.6603059170603,
#  517.157826866755,
#  513.3596274290642,
#  510.2361402550528,
#  507.75880843812365,
#  505.9000534468372,
#  504.63324404310436,
#  503.9326661559298,
#  503.77349368177556,
#  504.13176018349077,
#  504.98433146059193,
#  506.30887896449565,
#  508.08385403310206,
#  510.2884629198945,
#  512.9026425934696,
#  515.9070372841328,
#  519.2829757548998,
#  523.0124492749279,
#  527.0780902740541,
#  531.4631516577695,
#  536.1514867625698,
#  541.1275299322375,
#  546.3762776961844,
#  551.8832705315599,
#  557.6345751913792,
#  563.616767581456,
#  569.816916169447,
#  576.2225659098186,
#  582.821722669028,
#  589.602838135693,
#  596.5547952009756,
#  603.6668937948525,
#  610.9288371643815,
#  618.3307185804838,
#  625.8630084601753,
#  633.5165418915707,
#  641.2825065493671,
#  649.1524309888854,
#  657.1181733071073,
#  665.1719101594924,
#  673.306126121703,
#  681.5136033856878,
#  689.7874117798964,
#  698.1208991037065,
#  706.5076817664419,
#  714.9416357216534,
#  723.4168876876149,
#  731.9278066452621,
#  740.4689956050615,
#  749.0352836345639,
#  757.6217181386348,
#  766.2235573846064,
#  774.8362632648243,
#  783.4554942892919,
#  792.0770988013354,
#  800.6971084094298,
#  809.3117316285277,
#  817.9173477244426,
#  826.5105007550261,
#  835.0878938020728,
#  843.64638338807,
#  852.1829740720859,
#  860.6948132192629,
#  869.1791859385555,
#  877.633510183508,
#  886.0553320110275,
#  894.4423209932671,
#  902.7922657778702,
#  911.1030697919845,
#  919.3727470855798,
#  927.5994183097581,
#  935.7813068258516,
#  943.9167349412564,
#  952.004120268055,
#  960.0419722006077,
#  968.0288885084135,
#  975.9635520406429,
#  983.8447275388705,
#  991.6712585546175,
#  999.4420644684467,
#  1007.1561376074263,
#  1014.8125404578946,
#  1022.4104029705311,
#  1029.9489199548589,
#  1037.427348560363,
#  1044.8450058415156,
#  1052.2012664040653,
#  1059.495560130043,
#  1066.7273699790126,
#  1073.896229863155,
#  1081.001722593869,
#  1088.0434778976316,
#  1095.0211704989283,
#  1101.9345182681393,
#  1108.7832804323243,
#  1115.5672558469164,
#  1122.2862813263962,
#  1128.9402300320703,
#  1135.529009915147,
#  1142.0525622133505,
#  1148.5108599993698,
#  1154.903906779486,
#  1161.2317351407892,
#  1167.4944054454197,
#  1173.692004570349,
#  1179.8246446912199,
#  1185.8924621088606,
#  1191.895616117079,
#  1197.8342879104307,
#  1203.7086795306654,
#  1209.5190128506056,
#  1215.2655285942647,
#  1220.9484853920112,
#  1226.5681588696682,
#  1232.1248407704365,
#  1237.6188381085856,
#  1243.0504723538722,
#  1248.4200786456984,
#  1253.7280050360305,
#  1258.9746117601464,
#  1264.1602705343091,
#  1269.2853638794659,
#  1274.3502844701447,
#  1279.3554345077023,
#  1284.301225117134,
#  1289.1880757666675,
#  1294.0164137093827,
#  1298.7866734461393,
#  1303.4992962091,
#  1308.154729465169,
#  1312.7534264386863,
#  1317.2958456527288,
#  1321.7824504884084,
#  1326.213708761557,
#  1330.59009231622,
#  1334.912076634392,
#  1339.1801404614516,
#  1343.3947654467652,
#  1347.5564357989397,
#  1351.6656379552476,
#  1355.7228602647149,
#  1359.7285926844365,
#  1363.683326488648,
#  1367.5875539901228,
#  1371.4417682734756,
#  1375.2464629399649,
#  1379.0021318633867,
#  1382.7092689566912,
#  1386.3683679489395,
#  1389.9799221722465,
#  1393.5444243583627,
#  1397.062366444553,
#  1400.534239388458,
#  1403.9605329916008,
#  1407.3417357312637,
#  1410.6783346004106,
#  1413.9708149553853,
#  1417.219660371109,
#  1420.425352503501,
#  1423.5883709588677,
#  1426.7091931700088,
#  1429.7882942788005,
#  1432.8261470250172,
#  1435.8232216411645,
#  1438.7799857531054,
#  1441.6969042862686,
#  1444.5744393772252,
#  1447.4130502904507,
#  1450.2131933400592,
#  1452.975321816341,
#  1455.6998859169134,
#  1458.387332682318,
#  1461.038105935887,
#  1463.6526462277225,
#  1466.2313907826338,
#  1468.7747734518691,
#  1471.2832246685068,
#  1473.757171406359,
#  1476.1970371422458,
#  1478.6032418215145,
#  1480.9762018266729,
#  1483.3163299490066,
#  1485.6240353630733,
#  1487.8997236039431,
#  1490.143796547083,
#  1492.3566523907748,
#  1494.5386856409582,
#  1496.690287098405,
#  1498.811843848122,
#  1500.9037392508872,
#  1502.966352936831,
#  1505.0000608009777,
#  1507.0052350006529,
#  1508.9822439546851,
#  1510.9314523443136,
#  1512.8532211157353,
#  1514.7479074842115,
#  1516.6158649396596,
#  1518.457443253668,
#  1520.2729884878709,
#  1522.0628430036033,
#  1523.827345472795,
#  1525.566830890028,
#  1527.2816305857077,
#  1528.9720722402922,
#  1530.6384798995248,
#  1532.2811739906165,
#  1533.9004713393388,
#  1535.4966851879585,
#  1537.070125213994,
#  1538.6210975497288,
#  1540.149904802452,
#  1541.6568460753756,
#  1543.142216989194,
#  1544.606309704248,
#  1546.0494129432543,
#  1547.471812014569,
#  1548.8737888359394,
#  1550.2556219587327,
#  1551.6175865925866,
#  1552.9599546304694,
#  1554.2829946741108,
#  1555.5869720597796,
#  1556.8721488843767,
#  1558.1387840318273,
#  1559.387133199734,
#  1560.617448926279,
#  1561.8299806173468,
#  1563.024974573841,
#  1564.2026740191893,
#  1565.363319126998,
#  1566.5071470488463,
#  1567.6343919422052,
#  1568.7452849984543,
#  1569.8400544709816,
#  1570.9189257033602,
#  1571.9821211575693,
#  1573.0298604422605,
#  1574.0623603410386,
#  1575.0798348407623,
#  1576.082495159834,
#  1577.0705497764789,
#  1578.0442044569963,
#  1579.0036622839648,
#  1579.949123684407,
#  1580.8807864578873,
#  1581.7988458045434,
#  1582.703494353034,
#  1583.5949221884,
#  1584.4733168798298,
#  1585.338863508317,
#  1586.1917446942052,
#  1587.0321406246117,
#  1587.8602290807262,
#  1588.6761854649756,
#  1589.4801828280433,
#  1590.27239189575,
#  1591.0529810957792,
#  1591.8221165842401,
#  1592.5799622720822,
#  1593.3266798513305,
#  1594.0624288211575,
#  1594.7873665137754,
#  1595.501648120156,
#  1596.2054267155595,
#  1596.898853284886,
#  1597.5820767478306,
#  1598.2552439838555,
#  1598.9184998569592,
#  1599.571987240255,
#  1600.215847040347,
#  1600.8502182215047,
#  1601.4752378296366,
#  1602.0910410160598,
#  1602.697761061058,
#  1603.295529397241,
#  1603.884475632681,
#  1604.4647275738562,
#  1605.0364112483694,
#  1605.599650927458,
#  1606.1545691482993,
#  1606.701286736091,
#  1607.2399228259274,
#  1607.7705948844555,
#  1608.2934187313215,
#  1608.8085085604012,
#  1609.3159769608155,
#  1609.815934937733,
#  1610.3084919329588,
#  1610.7937558453102,
#  1611.2718330507762,
#  1611.7428284224666,
#  1612.2068453503498,
#  1612.6639857607765,
#  1613.1143501357924,
#  1613.5580375322438,
#  1613.9951456006695,
#  1614.4257706039841,
#  1614.8500074359608,
#  1615.2679496394933,
#  1615.6796894246684,
#  1616.085317686618,
#  1616.484924023182,
#  1616.8785967523534,
#  1617.2664229295365,
#  1617.648488364596,
#  1618.0248776387084,
#  1618.3956741210168,
#  1618.7609599850905,
#  1619.120816225187,
#  1619.4753226723235,
#  1619.8245580101513,
#  1620.1685997906445,
#  1620.5075244495956,
#  1620.841407321926,
#  1621.1703226568093,
#  1621.4943436326055,
#  1621.8135423716203,
#  1622.1279899546716,
#  1622.4377564354897,
#  1622.742910854919,
#  1623.0435212549678,
#  1623.3396546926574,
#  1623.6313772537142,
#  1623.918754066082,
#  1624.2018493132655,
#  1624.4807262475038,
#  1624.7554472027762,
#  1625.0260736076434,
#  1625.2926659979225,
#  1625.5552840291996,
#  1625.8139864891828,
#  1626.0688313098942,
#  1626.3198755797025,
#  1626.5671755552044,
#  1626.8107866729426,
#  1627.0507635609824,
#  1627.287160050326,
#  1627.520029186183,
#  1627.7494232390918,
#  1627.9753937158928,
#  1628.197991370557,
#  1628.4172662148708,
#  1628.633267528984,
#  1628.8460438718112,
#  1629.0556430912902,
#  1629.2621123345189,
#  1629.4654980577418,
#  1629.6658460362075,
#  1629.8632013738982,
#  1630.0576085131188,
#  1630.2491112439634,
#  1630.437752713655,
#  1630.62357543575,
#  1630.8066212992294,
#  1630.9869315774552,
#  1631.1645469370133,
#  1631.339507446432,
#  1631.5118525847804,
#  1631.6816212501526,
#  1631.8488517680332,
#  1632.0135818995466,
#  1632.1758488495962,
#  1632.3356892748895,
#  1632.493139291853,
#  1632.6482344844374,
#  1632.801009911815,
#  1632.9515001159693,
#  1633.0997391291855,
#  1633.2457604814254,
#  1633.3895972076116,
#  1633.5312818548,
#  1633.6708464892629,
#  1633.8083227034633,
#  1633.9437416229407,
#  1634.0771339130881,
#  1634.2085297858503,
#  1634.337959006315,
#  1634.4654508992166,
#  1634.5910343553512,
#  1634.7147378378904,
#  1634.8365893886246,
#  ...]

# %%
W = np.linspace(0, max(x), 1000)
B = np.linspace(0, max(y), 1000)

WW, BB = np.meshgrid(W, B)
temp = np.zeros([len(W), len(B)])
for i in range(len(W)):
    for j in range(len(B)):
        yy = WW[i, j] * np.array(x) + BB[i, j]
        temp[i, j] = 1 / len(np.array(x)) * sum((np.array(y) - yy) ** 2)

# %%
yy

# %%
data

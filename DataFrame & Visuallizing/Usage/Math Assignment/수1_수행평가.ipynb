# %% [markdown]
# <a href="https://colab.research.google.com/github/II-DW/Colab-Storage/blob/main/%EC%88%981_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.linspace(-8 * np.pi, 8 * np.pi, 2000)
Y=np.sin(X)

# %%
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = sin θ')
plt.show()

# %%
Y2=np.cos(X)
plt.plot(X, Y2)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = cos θ')
plt.show()

# %%
X=np.linspace(0, 128, 200000)
Y1 = 15 * np.sin(2 * np.pi * X)
Y2 = 15 * np.sin(4 * np.pi * X)
Y3 = 15 * np.sin(6 * np.pi * X)
Y4 = 15 * np.sin(8 * np.pi * X)
Y5 = 15 * np.sin(10 * np.pi * X)

# %%
sub_plots = plt.subplots(5, 1, figsize=(10,50))
fig = sub_plots[0]
graph = sub_plots[1]

graph[0].plot(X, Y1)
graph[1].plot(X, Y2)
graph[2].plot(X, Y3)
graph[3].plot(X, Y4)
graph[4].plot(X, Y5)

graph[0].set_title('15 * sin 2t')
graph[1].set_title('15 * sin 4t')
graph[2].set_title('15 * sin 6t')
graph[3].set_title('15 * sin 8t')
graph[4].set_title('15 * sin 10t')


graph[0].axvline(x=0, color = 'black')  # draw x =0 axes
graph[0].axhline(y=0, color = 'black')   # draw y =0 axes

graph[1].axvline(x=0, color = 'black')  # draw x =0 axes
graph[1].axhline(y=0, color = 'black')   # draw y =0 axes

graph[2].axvline(x=0, color = 'black')  # draw x =0 axes
graph[2].axhline(y=0, color = 'black')   # draw y =0 axes

graph[3].axvline(x=0, color = 'black')  # draw x =0 axes
graph[3].axhline(y=0, color = 'black')   # draw y =0 axes

graph[4].axvline(x=0, color = 'black')  # draw x =0 axes
graph[4].axhline(y=0, color = 'black')   # draw y =0 axes

graph[0].set_xlim([-0.1, 2])
graph[1].set_xlim([-0.1, 2])
graph[2].set_xlim([-0.1, 2])
graph[3].set_xlim([-0.1, 2])
graph[4].set_xlim([-0.1, 2])

plt.show()

# %%
Y = Y1 + Y2 + Y3 + Y4 + Y5

# %%
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('Sum Of sin t')
plt.xlim([-0.1, 2])

plt.show()

# %%
X=np.linspace(0, 128, 200000)
Y1 = 15 * np.cos(2 * np.pi * X)
Y2 = 15 * np.cos(4 * np.pi * X)
Y3 = 15 * np.cos(6 * np.pi * X)
Y4 = 15 * np.cos(8 * np.pi * X)
Y5 = 15 * np.cos(10 * np.pi * X)

# %%
sub_plots = plt.subplots(5, 1, figsize=(10,50))
fig = sub_plots[0]
graph = sub_plots[1]

graph[0].plot(X, Y1)
graph[1].plot(X, Y2)
graph[2].plot(X, Y3)
graph[3].plot(X, Y4)
graph[4].plot(X, Y5)

graph[0].set_title('15 * cos 2t')
graph[1].set_title('15 * cos 4t')
graph[2].set_title('15 * cos 6t')
graph[3].set_title('15 * cos 8t')
graph[4].set_title('15 * cos 10t')


graph[0].axvline(x=0, color = 'black')  # draw x =0 axes
graph[0].axhline(y=0, color = 'black')   # draw y =0 axes

graph[1].axvline(x=0, color = 'black')  # draw x =0 axes
graph[1].axhline(y=0, color = 'black')   # draw y =0 axes

graph[2].axvline(x=0, color = 'black')  # draw x =0 axes
graph[2].axhline(y=0, color = 'black')   # draw y =0 axes

graph[3].axvline(x=0, color = 'black')  # draw x =0 axes
graph[3].axhline(y=0, color = 'black')   # draw y =0 axes

graph[4].axvline(x=0, color = 'black')  # draw x =0 axes
graph[4].axhline(y=0, color = 'black')   # draw y =0 axes

graph[0].set_xlim([-0.1, 2])
graph[1].set_xlim([-0.1, 2])
graph[2].set_xlim([-0.1, 2])
graph[3].set_xlim([-0.1, 2])
graph[4].set_xlim([-0.1, 2])

plt.show()

# %%
Y = Y1 + Y2 + Y3 + Y4 + Y5

# %%
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('Sum Of cos t')
plt.xlim([-0.1, 2])

plt.show()

# %%
X=np.linspace(0, 128, 200000)
Y1 = 15 * np.cos(2 * np.pi * X)
Y2 = 15 * np.cos(4 * np.pi * X)
Y3 = 15 * np.cos(6 * np.pi * X)
Y4 = 15 * np.cos(8 * np.pi * X)
Y5 = 15 * np.cos(10 * np.pi * X)
Y_s_1 = Y1 + Y2 + Y3 + Y4 + Y5

Y1 = 15 * np.sin(2 * np.pi * X)
Y2 = 15 * np.sin(4 * np.pi * X)
Y3 = 15 * np.sin(6 * np.pi * X)
Y4 = 15 * np.sin(8 * np.pi * X)
Y5 = 15 * np.sin(10 * np.pi * X)
Y_s_2 = Y1 + Y2 + Y3 + Y4 + Y5
Y = Y_s_1 + Y_s_2

# %%
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('Sum')
plt.xlim([-0.1, 2])

plt.show()

# %%
plt.plot(X, Y + 25)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('Sum')
plt.xlim([-0.1, 2])

plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.sin(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = sin θ')
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = cos θ')
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.cos(X) * np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = cos θ')
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y= np.cos(2*X) * np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y= np.sin(X) * np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.sin(2*X) * np.sin(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = cos θ')
plt.ylim([-1, 1])

plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.sin(X) * np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.title('y = cos θ')
plt.ylim([-1, 1])

plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.sin(X) * np.sin(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y= np.sin(2*X) * np.sin(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y= np.sin(X) * np.cos(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])
plt.show()

# %%
X=np.linspace(0, 2 * np.pi, 2000)
Y=np.sin(2*X) * np.sin(X)
plt.plot(X, Y)
plt.axvline(x=0, color = 'black')  # draw x =0 axes
plt.axhline(y=0, color = 'black')   # draw y =0 axes
plt.ylim([-1, 1])

plt.show()

# %%
n = int(input("0 이상의 정수를 입력하세요 : "))

x = 0
Prime_factors_L = []

while True :
  for x in range (2, int(n+1)) : # 2 ~ n 까지 반복
    if n % x == 0 :
      Prime_factors_L.append(x)
      n = n/x
      break
  print(n)
  if n == 1 :

    break

Prime_factors_L
# Out:
# 0 이상의 정수를 입력하세요 : 10
# 5.0
# 1.0
# [2, 5]

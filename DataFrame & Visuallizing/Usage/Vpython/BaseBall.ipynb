# %%
from sympy import Symbol, solve

g = 9.80665 #(m/s^2)

x=Symbol('x')
equation = (122.5 / (3**0.5) ) - g * (x**2) / 2 - 3.6
solve(equation)
# Out:
# [-3.69996937326808, 3.69996937326808]

# %%
import numpy as np
245 / ((3.6999)*np.sqrt(3))
# Out:
# 38.23098352697595

# %%
105 * 2**0.5
# Out:
# 148.49242404917499

# %%
from sympy import Symbol, solve

g = 9.80665 #(m/s^2)

x=Symbol('x')
equation = (40.7675/2)*x- g * (x**2) / 2
solve(equation)
# Out:
# [0.0, 4.15712807125777]

# %%
4.15712807125777 / 2 * 40.7675 * 3**0.5
# Out:
# 146.770277671195

# %%
(40.7675**2) * 1/4 / (2 *g)
# Out:
# 21.184464830625135
